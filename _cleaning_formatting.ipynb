# %%
import numpy as np
import pandas as pd
import math as math
import matplotlib.pyplot as plt
import json
from typing import List

# %% [markdown]
# # Clean the OpenFoodFact dataset

# %%
data_products = pd.read_csv('products_clean.csv', sep = ';')

# %%
data_products.head(100)
# Out:
#               code                                       product_name  \
# 0    0000000290616                                       Salade Cesar
# 1    0000000491228                             Entremets Crème Brulée
# 2    0000001938067                       Chaussons tressés aux pommes
# 3    0000004302544                                Pain Burger Artisan
# 4       0000005016                   Pesto à La Roquette Bio Kazidomi
# ..             ...                                                ...
# 95  00041500007007                                     Yellow Mustard
# 96        00043366  Salade à la Mexicaine au Maïs doux, Poivrons, ...
# 97        00051248       Winter Berries & Prosecco Hand cooked crisps
# 98        00062145                                      fat free milk
# 99        00065252                     4 Ultimate Buttermilk pancakes
#
#                                       categories_tags  \
# 0   en:plant-based-foods-and-beverages|en:plant-ba...
# 1   en:dairies|en:desserts|en:dried-products|en:da...
# 2   en:snacks|en:sweet-snacks|en:biscuits-and-cake...
# 3                                         fr:boulange
# 4                    en:groceries|en:sauces|en:pestos
# ..                                                ...
# 95   en:groceries|en:condiments|en:sauces|en:mustards
# 96  en:plant-based-foods-and-beverages|en:plant-ba...
# 97  en:plant-based-foods-and-beverages|en:plant-ba...
# 98               en:dairies|en:milks|en:skimmed-milks
# 99                                        en:pancakes
#
#                                         categories_en           countries_en  \
# 0   Plant-based foods and beverages|Plant-based fo...                 Canada
# 1   Dairies|Desserts|Dried products|Dairy desserts...                 France
# 2   Snacks|Sweet snacks|Biscuits and cakes|Viennoi...                 Canada
# 3                                         fr:boulange                 Canada
# 4                             Groceries|Sauces|Pestos         Belgium|France
# ..                                                ...                    ...
# 95               Groceries|Condiments|Sauces|Mustards          United States
# 96  Plant-based foods and beverages|Plant-based fo...                 France
# 97  Plant-based foods and beverages|Plant-based fo...  France|United Kingdom
# 98                        Dairies|Milks|Skimmed milks          United States
# 99                                           Pancakes                 France
#
#                                      ingredients_text          allergens  \
# 0   INGREDIENTS : LAITUE. VINAIGRETTE (HUILE DE CA...                NaN
# 1   Sucre| poudre de _lait_| poudre au beurre (_la...                NaN
# 2   Pâte (farine| margarines d'huile de palme et d...                NaN
# 3   Ingrédients : Farine| eau| sel| levure| orge m...                NaN
# 4   Rucola à l'huile d'olive vierge extra* 39% (ru...    en:milk|en:nuts
# ..                                                ...                ...
# 95  DISTILLED WHITE VINEGAR| WATER| MUSTARD SEED| ...                NaN
# 96  Maïs doux (15%) • Poivrons rouges (14%) • Riz ...                NaN
# 97  Pommes de terre| Huile de tournesol| Sucre| Ac...                NaN
# 98    FAT FREE MILK| VITAMIN A PALMITATE| VITAMIN D3.                NaN
# 99  Babeurre (_Lait_) (31 %) Farine de blé contien...  en:gluten|en:milk
#
#    nutriscore_grade  nova_group                       main_category  ...  \
# 0                 c         4.0                  en:leaf-vegetables  ...
# 1                 b         4.0  en:dried-products-to-be-rehydrated  ...
# 2                 c         4.0                  en:apple-turnovers  ...
# 3                 b         3.0                         fr:boulange  ...
# 4                 e         3.0                           en:pestos  ...
# ..              ...         ...                                 ...  ...
# 95                c         3.0                         en:mustards  ...
# 96                b         3.0               en:refrigerated-meals  ...
# 97                d         4.0          en:flavoured-potato-crisps  ...
# 98                a         1.0                    en:skimmed-milks  ...
# 99                b         4.0                         en:pancakes  ...
#
#     fat_100g  saturated-fat_100g  trans-fat_100g  cholesterol_100g  \
# 0      12.00               7.000             NaN           0.05600
# 1      15.30              11.200             NaN               NaN
# 2      10.70               2.000           0.667           0.00533
# 3       1.11               0.333           0.000           0.00000
# 4      53.20               9.600             NaN               NaN
# ..       ...                 ...             ...               ...
# 95      0.00               0.000           0.000           0.00000
# 96      5.20               0.700             NaN               NaN
# 97     30.00               3.000             NaN               NaN
# 98      0.00               0.000             NaN               NaN
# 99      7.70               0.900             NaN               NaN
#
#     carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# 0                 23.0         0.00        2.00          22.00      2.160
# 1                 75.5        69.80        0.10           6.80      0.500
# 2                 38.7        24.70        2.00           3.33      0.647
# 3                 53.3         1.11        2.22          10.00      1.520
# 4                 11.7         0.50        1.30           8.20      2.700
# ..                 ...          ...         ...            ...        ...
# 95                 0.0         0.00        0.00           0.00      3.300
# 96                18.8         3.20        2.80           3.10      0.550
# 97                54.1         3.00         NaN           6.80      0.700
# 98                 5.0         4.58        0.00           3.33      0.101
# 99                37.4         9.50        2.00           6.90      0.670
#
#     sodium_100g
# 0        0.8640
# 1        0.2000
# 2        0.2590
# 3        0.6100
# 4        1.0800
# ..          ...
# 95       1.3200
# 96       0.2200
# 97       0.2800
# 98       0.0402
# 99       0.2680
#
# [100 rows x 21 columns]

# %%
len(data_products)
# Out:
# 71782

# %%
def clean():
    # Strips
    data_products['ingredients_text'] = data_products['ingredients_text'].str.strip()
    data_products['ingredients_text'] = data_products['ingredients_text'].str.strip('|')
    data_products['ingredients_text'] = data_products['ingredients_text'].str.strip('`')
    data_products['ingredients_text'] = data_products['ingredients_text'].str.strip('´')
    data_products['ingredients_text'] = data_products['ingredients_text'].str.strip('"')
    data_products['ingredients_text'] = data_products['ingredients_text'].str.strip('\'')
    # Replace all multiple spaces to ' '
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace =' +', value = ' ', regex = True)
    # Replace all multiple '|' to '|'
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\|+', value = '|', regex = True)
    # Remove space '|' before and after
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='[ ]?\|[ ]?', value = '|', regex = True)
    # Replace all "' \w" to "'\w"
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='(\'|’)[ ]+', value = '\'', regex = True)

def firstClean():
    # Remove all language tag for categories
    data_products['categories_tags'] = data_products['categories_tags'].replace(to_replace ='\w{2}:', value = '', regex = True)
    data_products['main_category'] = data_products['main_category'].replace(to_replace ='\w{2}:', value = '', regex = True)
    data_products['countries_en'] = data_products['countries_en'].replace(to_replace ='\w{2}:', value = '', regex = True)
    data_products['categories_en'] = data_products['categories_en'].replace(to_replace ='\w{2}:', value = '', regex = True)
    data_products['allergens'] = data_products['allergens'].replace(to_replace ='(?!en):\w+', value = '', regex = True)
    data_products['allergens'] = data_products['allergens'].replace(to_replace ='\w{2}:', value = '', regex = True)
#     # Replace ' ' to '-'
#     data_products['countries_en'] = data_products['countries_en'].replace(to_replace =' ', value = '-', regex = True)
#     data_products['countries_en'] = data_products['countries_en'].str.lower()
    
    
    
    # Lower case column
    data_products['ingredients_text'] = data_products['ingredients_text'].str.lower()
    # Replace special character
    data_products['ingredients_text'] =  data_products['ingredients_text'].replace(to_replace ='œ', value = 'oe', regex = True)
    data_products['ingredients_text'] =  data_products['ingredients_text'].replace(to_replace ='ﬁ', value = 'fi', regex = True)
    data_products['ingredients_text'] =  data_products['ingredients_text'].replace(to_replace =' +', value = ' ', regex = True)
    
    clean()
    
    # Remove all unuseful character (™,!,#,=,^,$,@,❤,®,±,°,¹,²,³,¼,½,¾,º)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='(™|!|#|=|\+|\-|\^|\$|@|❤|®|±|°|¹|²|³|¼|½|¾|º)', value = '', regex = True)
    # Remove common unuseful text 'ingredients :'
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='(ingredients|ingredient|ingrédients|ingrédient)[ ]?[:]?[ ]?', value = '', regex = True)
    # Remove all language tag
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\w{2}:', value = '', regex = True)
    
    # Replace all (_, ') to ' '
    data_products['ingredients_text'] =  data_products['ingredients_text'].replace(to_replace ='(_| \')', value = ' ', regex = True)
    # Remove all '<balise>' and '</balise>'
    data_products['ingredients_text'] =  data_products['ingredients_text'].replace(to_replace ='<(\/)?(\w){1,20}>', value = '', regex = True)
    # Remove all '(+33°)' and '+23°'
    data_products['ingredients_text'] =  data_products['ingredients_text'].replace(to_replace ='(\(|（)?[ ]?(\+|\-)?[ ]?\d{1,5}(?:\.\d+)?[ ]?°[ ]?(\)|）)?', value = '', regex = True)
    # Remove all quantities '40g'
    data_products['ingredients_text'] =  data_products['ingredients_text'].replace(to_replace ='\d+(\.\d+)?[ ]?(mg|g|kg|ml|cl|l|kj|oz|µg|pg|ug)', value = '', regex = True)
    # Remove all ref 
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\w?\d{1,4}\w?', value = '', regex = True)
    # Remove all '(33%)', '{33%}' and '33%'
    data_products['ingredients_text'] =  data_products['ingredients_text'].replace(to_replace ='(\(|\{)?[ ]?\d{1,3}(?:\.\d+)?[ ]?(\%|％)[ ]?(\)|\})?', value = '', regex = True)

     # Replace seperation characters to '|' (and, , ,:,*,;,[,],{,},&,•,%,％,‰,.,·,/,<,>,-,—,‘,’,“,⁸,€,℅,⅓,⅕,●,♦,、,。,一,﻿,（,）,(,),，,~,«,»,¡,¤,§)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='( and |\,|\:|\*|;|\[|\]|\{|\}|\&|•|%|％|‰|\.|·|\/|<|>|—|‘|’|“|⁸|€|℅|⅓|⅕|●|♦|、|。|一|﻿|（|）|\(|\)|，|~|«|»|¡|¤|§)', value = '|', regex = True)
    
    clean()
    
def lastClean():
    # Remove all ingredients too small
    for x in range(5):
        data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='^.{1,2}$', value = '', regex = True)
        data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='^.{1,2}\|', value = '', regex = True)
        data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\|.{1,2}$', value = '', regex = True)
        data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\|.{1,2}\|', value = '|', regex = True)
    
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='^\'', value = '', regex = True)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\|\'', value = '|', regex = True)
    
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='^\´', value = '', regex = True)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\|\´', value = '|', regex = True)
    
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='^ +', value = '', regex = True)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace =' +$', value = '', regex = True)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace =' +\|', value = '|', regex = True)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\| +', value = '|', regex = True)

    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='^ $', value = '', regex = True)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='^ \|', value = '', regex = True)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\| $', value = '', regex = True)
    data_products['ingredients_text'] = data_products['ingredients_text'].replace(to_replace ='\| \|', value = '|', regex = True)
    
    clean()

# %%
firstClean()
lastClean()
data_products = data_products.where(data_products.notnull(), None)

# %% [markdown]
# ### Verify the data

# %%
i = 400
iStop = i + 100
while i < iStop:
    print("---")
    print(i)
    print("---")
    print(data_products['ingredients_text'][i])
    i += 1
# Out:
# ---
# 400
# ---
# soybean oil|water|vinegar|whey|from milk|sugar|salt|contains less than|of modified food starch|black peppercorn|dried garlic|xanthan gum|phosphoric acid|polysorbate|lactic acid|natural flavor|sorbic acid|calcium disodium edta|to protect flavor|contai milk
# ---
# 401
# ---
# enriched macaroni product|wheat flour|niacin|ferrous sulfate|iron|thiamin mononitrate|vitamin|riboflavin|vitamin|folic acid|cheese sauce mix|whey|milk|salt|skim milk|milkfat|milk protein concentrate|modified food starch|contains less than|of sodium tripolyphosphate|buttermilk solids|sodium|phosphate|citric acid|cellulose gel|cellulose gum|lactic acid|cheese culture|calcium phosphate|yellow|yellow|enzymes
# ---
# 402
# ---
# water|vinegar|sugar|soybean oil|salt|garlic|contains less than|of citric acid|red bell peppers onions|quot|xanthan gum|modified food starch|spice|potassium sorbate|calcium disodium edta|to protect flavor|dried
# ---
# 403
# ---
# tomato concentrate|high fructose corn syrup|distilled vinegar|corn syrup|salt|contains less than|spice|onion powder|natural flavors
# ---
# 404
# ---
# chocolate liquor|cocoa butter|sugar|cocoa powder|natural flavor
# ---
# 405
# ---
# pasteurized partskim milk|cheese culture|salt|enzymes
# ---
# 406
# ---
# lowfat milk|vitamin a palmitate|vitamin
# ---
# 407
# ---
# cultured|pasteurized grade a non fat milk|milk protein concentrate|organic corn starch|vitamin a acetate|vitamin
# ---
# 408
# ---
# pork|salt|sugar|wine|spices|dextrose|garlic|ascorbic acid|lactic acid starter culture|rosemary extract|sodium nitrite|sodium nitrate
# ---
# 409
# ---
# ham cured with water|contains|or less of the followi vinegar|dextrose|salt sodium phosphate|sodium erythorbate|sodium nitrite
# ---
# 410
# ---
# unbleached enriched wheat flour|wheat flour|malted barley flour|niacin|reduced iron|thiamin mononitrate|riboflavin|folic acid|water|yeast|sugar|corn meal|wheat gluten|fumaric acid|lactic acid|malic acid|acetic acid|sea salt|calcium propíonate|sorbic acid|to retard spoilage|ascorbic acid|enzymes|contai wheat
# ---
# 411
# ---
# almonds|canola and|or peanut and|or cottonseed oil|salt
# ---
# 412
# ---
# water|apple juice concentrate|ascorbic acid|vitamin c
# ---
# 413
# ---
# tomato juice from concentrate|filtered water|tomato concentrate|reconstituted vegetable juice blend|filtered water|concentrated juices of carrots|celery|beets|parsley|lettuce|watercress|spinach|salt|ascorbic acid|vitamin c|natural flavors|citric acid
# ---
# 414
# ---
# durum wheat semolina|niacin|iron|ferrous sulfate|thiamin mononitrate|riboflavin|folic acid
# ---
# 415
# ---
# high fructose corn syrup|tomato concentrate|tomato paste|water|distilled vinegar|modified corn starch|less than|salt|pineapple juice concentrate|molasses|caramel color|spices|xanthan gum|smoke flavor|sodium benzoate|as preservative|garlic powder|corn syrup|sugar|tamarind|natural flavor
# ---
# 416
# ---
# water|cream|cheese blend|granular|parmesan|and romano cheese made from cow's milk|milk|cheese cultures|salt|enzymes|water|whey|salt|lactic acid|citric acid|modified corn starch|enzyme modified egg yolks|egg yolks|salt|enzymes|chablis wine|sugar|butter|cream|natural flavor|salt|sodium phosphate|dried garlic|gum arabic|guar gum|spice|natural flavors
# ---
# 417
# ---
# tomato puree|water|tomato paste|canola oil|sugar|salt|vinegar|dehydrated onion|basil|spices|dehydrated garlic|natural flavor
# ---
# 418
# ---
# corn oil
# ---
# 419
# ---
# farine de maïs biologique|farine de riz biologique
# ---
# 420
# ---
# sugar|cinnamon
# ---
# 421
# ---
# beef|salt|dextrose|spices|smoke flavoring|natural flavors|lactic acid starter culture|sodium erythorbate|sodium nitrate
# ---
# 422
# ---
# unbleached enriched flour|wheat flour|niacin|reduced iron|thiamine mononitrate|riboflavin|folic acid|sugar|palm oil|cinnamon|natural flavor|sodium bicarbonate|salt
# ---
# 423
# ---
# sweet potatoes|sunflower oil|sea salt
# ---
# 424
# ---
# sugar|corn syrup|hydrogenated palm kernel oil|less than|citric acid|tapioca dextrin|gelatin|apple juice from concentrate|modified corn starch|natural|artificial flavors|colors|red|yellow|yellow|blue
# ---
# 425
# ---
# sugar|corn syrup|hydrogenated palm kernel oil|less than|citric acid|tapioca dextrin|modified corn starch|natural|artificial flavors|colors|red ake|titanium dioxide|red|yellow ake|yellow|yellow ake|yellow|blue ake|blue|blue ake|sodium citrate|carnauba wax
# ---
# 426
# ---
# sugar|corn syrup|hydrogenated palm kernel oil|less than|citric acid|tapioca dextrin|modified corn starch|natural|artificial flavors|colors|titanium dioxide|red ake|yellow ake|yellow ake|blue ake|blue|blue ake|yellow|yellow|red|sodium citrate|carnauba wax
# ---
# 427
# ---
# sugar|gum arabic|natural|artificial flavors|gelatin|colors|blue|yellow
# ---
# 428
# ---
# beef
# ---
# 429
# ---
# pâtes cuites|semoule de blé dur|contient gluten|eau|lait demiécrémé|blanc de poulet cuit|crème britannique|lait|eau|fromage à pâte dure|lait|bacon fumé cuit|viande de porc|sels de salaison|sel|conservate nitrite de sodium|eau antioxydant|huile de colza|fromage parmesan|lait|fécule de maïs|jus de citron|sel|fromage regato|lait|persil|farine de blé|contient gluten|purée d'ail|ail|fécule de pomme de terre|stabilisa pectine|poivre noir grossièrement moulu
# ---
# 430
# ---
# châtaignes|sucre|marrons glacés|sirop de glucose|eau|extrait de vanille madagascar
# ---
# 431
# ---
# châtaignes|sucre|marrons glacés|sirop de glucose|eau|extrait naturel de vanille
# ---
# 432
# ---
# châtaignes|sucre|marrons glacés|sirop de glucose|eau|extrait naturel de vanille
# ---
# 433
# ---
# châtaignes|sucre|marrons glacés|sirop de glucose|eau|extrait naturel de vanille préparé avec de fruits pour teneur totale en sucres pour sans gluten
# ---
# 434
# ---
# châtaignes|sucre|débris de marrons glacés écrasés|marrons|sucre|sirop de glucose|arôme naturel de vanille|eau|sirop de glucose|arôme naturel de vanille
# ---
# 435
# ---
# châtaignes|sucre|marrons glacés|sirop de glucose|eau|extrait naturel de vanille
# ---
# 436
# ---
# châtaignes|sucre|marrons glacés|sirop de glucose|eau|extrait naturel de vanille
# ---
# 437
# ---
# châtaignes|sucre|débris de marrons glacés écrasés|marrons|sucre|sirop de glucose|arôme naturel vanille|eau|sirop de glucose|arôme naturel vanille
# ---
# 438
# ---
# châtaignes|sucre|marrons glacés|sirop de glucose|eau|extrait naturel de vanille
# ---
# 439
# ---
# châtaignes|sucre|marrons glacés|sirop de glucose|eau|extrait naturel de vanille
# ---
# 440
# ---
# châtaignes|sucre|marrons glacés|sirop de glucose|eau|extrait naturel de vanille
# ---
# 441
# ---
# châtaignes|eau
# ---
# 442
# ---
# marrons|sucre|sirop de glucose|arôme naturel vanille
# ---
# 443
# ---
# enriched yellow corn|yellow corn|thiamine mononitrate|riboflavin|niacin|ferrous sulfate|folic acid|vegetable oil|contains one or more corn oil|sunflower oil|canola oil|whey|corn starch|salt|color blend|whey|yellow|yellow|monosodium glutamate|lactic acid|cheese blend|whey|cheddar cheese|whole milk|culture|salt|enzymes|salt|butter|buttermilk|disodium phosphate|natural flavors|yellow|oleoresin turmeric|maltodextrin|natural|artificial flavors|citric acid|yellow ake|yellow ake|fructose
# ---
# 444
# ---
# reduced fat milk|vitamin a|palmitiate|vitamin
# ---
# 445
# ---
# mechanically|expeller|pressed naturally unrefined virgin organic coconut oil
# ---
# 446
# ---
# marionberries|strawberries|blueberries|red raspberries|boysenberries
# ---
# 447
# ---
# gluten free oat flour|sugar|chocolate chips|sugar|cocoa mass|cocoa butter|emulsifi soya lecithin|flavouring|palm oil|margarine|palm fat|rapeseed oil|water|palm oil|salt|emulsifi mono|diglycerides of fatty acids|tapioca flour|rice flour|golden syrup|raising agen sodium bicarbonate|ammonium carbonate|stabilis xanthan gum|flavouring
# ---
# 448
# ---
# aceite de coco orgánico sin refinar extraído mecánicamente por presión
# ---
# 449
# ---
# enriched flour|wheat flour|niacin|reduced iron|thiamin mononitrate|vitamin|riboflavin|vitamin|folic acid|vegetable oil|contains one or more of the followi palm|canola|soybean with tbhq for freshness|contains two percent or less enzymes|yeast|malted barley flour|sodium sulfate|salt|leavening|baking soda
# ---
# 450
# ---
# pommes de terre|fromage cheddar affiné|lait|lait demiécrémé beurre|lait|sel de mer poivre noir concassé sel
# ---
# 451
# ---
# boneless|skinless chicken breast strips with rib meat|wheat flour|water|contains|or less of the followi brown sugar|corn starch|dried garlic|extractives of paprika|garlic powder|rice starch|salt|spices|spice extracts|breading set in vegetable oil
# ---
# 452
# ---
# carrots|breading|dried potatoes|rice flour|salt|spices|dried garlic|dried onion|maltodextrin|natural flavor|canola oil|green beans|spinach|zucchini|kale|water|batter|corn starch|yellow corn flour|rice flour|xanthan gum|potato flakes|broccoli|predust|corn starch|rice flour|spice|red roasted peppers|peas|onions|corn starch|sea salt|parsley|yeast extract|garlic powder|onion powder|vitamin mineral blend|ferric orthophosphate|niacinamide|zinc oxide|cyanocobalamin|maltodextrin|folic acid|thiamine mononitrate|pyridoxine hydrochloride|riboflavin|spice
# ---
# 453
# ---
# pears|water|high fructose corn syrup|sugar|corn syrup
# ---
# 454
# ---
# mandarines|eau|sucre|correcteur d'acidi acide citrique
# ---
# 455
# ---
# tomatoes|tomato juice|citric acid|calcium chloride
# ---
# 456
# ---
# abricots|eau|sirop de glucosefructose|sucre|affermissa chlorure de calcium
# ---
# 457
# ---
# fruits|pêches|poires|ananas|raisins|cerises avec colorant|eau|sucre|sirop de glucose|correcteur d'acidité|acide citrique
# ---
# 458
# ---
# pêches|eau|sirop de glucosefructose|sucre|correcteur d'acidi acide citrique
# ---
# 459
# ---
# corn|water|sea salt
# ---
# 460
# ---
# peaches|water|sugar|pear juice concentrate|natural flavor|ascorbic acid|to preserve color|lemon juice concentrate|citric acid
# ---
# 461
# ---
# abricots|eau|sirop de glucosefructose|sucre|antioxydant|acide citrique|raffermissant|chlorure de calcium
# ---
# 462
# ---
# tomates biologiques|sel|correcteur d'acidité|acide citrique
# ---
# 463
# ---
# tomates jaunes entières pelées|jus de tomates jaunes|correcteur d'acidité|acide citrique
# ---
# 464
# ---
# pêches|jus d'ananas à base de concentré|correcteur d'acidi acide citrique
# ---
# 465
# ---
# demipêches|jus naturel
# ---
# 466
# ---
# tomaten|tomatensaft|säureregulat citronensäure
# ---
# 467
# ---
# mezze pesche con edulcorante i pesche|acqua|edulcorante artificia sucralos|regolatore di acidita acido citrico
# ---
# 468
# ---
# fein gehackte tomaten|tomatensaft|fein gehacktes basilikum|säureregulat citronensäure
# ---
# 469
# ---
# tomates daterrini|jus de tomates|correcteur d'acidité|acide citrique
# ---
# 470
# ---
# ananas|jus d'ananas
# ---
# 471
# ---
# pezzi di ananas|succo di ananas chiarificato|zucchero|aroma naturale di limone
# ---
# 472
# ---
# water|corn|modified food starch|corn|sugar|sea salt
# ---
# 473
# ---
# peas|water|sugar
# ---
# 474
# ---
# tomates entières pelées biologiques|jus de tomates biologiques correcteur d'acidité|acide citrique
# ---
# 475
# ---
# tomates entières pelées biologiques|jus de tomates biologique|correcteur d'acidité|acide citrique
# ---
# 476
# ---
# beef broth|less than|of the followi salt|hydrogenated protein|soy|corn|wheat|monosodium glutamate|hydrolyzed whey protein|wheat bran protein dextrose|autolyzed yeast extract|caramel color|onion powder|thiamine hydrochloride|natural flavor|disodium inosinate|disodium guanylate
# ---
# 477
# ---
# dark chocolate|sugar|chocolate liquor|cocoa butter|butter oil|soy lecithin|an emulsifier|vanillin|an artificial flavor|coffee beans|gum arabic|tapioca dextrin|sucrose|corn syrup|coconut oil|xanthan gum|confectioner's glaze|packaged on shared equipment with peanuts|tree nuts|pecans|almonds|macadamia nuts|dairy|soy|wheat
# ---
# 478
# ---
# durum|wheat|semolina|niacin|ferrous lactate|thiamine mononitrate|riboflavin|folic acid
# ---
# 479
# ---
# enriched flour|wheat flour|niacin|reduced iron|vitamin|thiamin mononitrate|vitamin|riboflavin|folic acid|vegetable oil|soybean|palm oil with tbhq for freshness|cheese made with skim milk|skim milk|whey protein|cheese cultures|salt|enzymes|annatto extract color|contains|or less of salt|paprika|whey|buttermilk|cheddar|monterey jack cheese|milk|cheese cultures|salt|enzymes|tomato powder|garlic powder|yeast|monosodium glutamate|natural|artificial flavors|onion powder|corn syrup solids|paprika extract color|autolyzed yeast extract|disodium inosinate|disodium guanylate|malic acid|sugar|spice extract|annatto extract color|yellow|yellow|soy lecithin
# ---
# 480
# ---
# dextrose|enriched flour|wheat flour|niacin|reduced iron|thiamin mononitrate|vitamin|riboflavin|vitamin|folic acid|peanut butter|sugar|palm|soybean oils with tbhq|citric acid to protect flavor|palm|palm kernel oil|water|contains|or less of each of the followi soy flour|cocoa|soybean oil|salt|corn starch|mono|diglycerides|soy lecithin|baking soda|citric acid|artificial flavor|whey|milk|egg whites
# ---
# 481
# ---
# sugar|corn syrup|water|enriched bleached flour|wheat flour|niacin|reduced iron|thiamin mononitrate|vitamin|riboflavin|vitamin|folic acid|palm|soybean oils with tbhq|citric acid to protect flavor|dextrose|palm|palm kernel oil|contains|or less of each of the followi soy flour|cocoa|soybean oil|eggs|corn starch|whey|milk|leavening|baking soda|sodium aluminum phosphate|salt|sorbitan monostearate|colors|yellow|red|blu|sorbic acid|to preserve freshness|polysorbate|soy lecithin|mono|diglycerides|egg whites|natural|artificial flavors
# ---
# 482
# ---
# enriched wheat flour|wheat flour|niacin|reduced iron|thiamin mononitrate|vitamin|riboflavin|vitamin|folic acid|palm oil|water|sugar|dextrose|soybean oil|contains|or less of each of the followi modified corn starch|leavening|baking soda|sodium acid pyrophosphate|sodium aluminum phosphate|dried egg yolks|nonfat dry milk|titanium dioxide|glycerin|corn syrup solids|defatted soy flour|preservatives|calcium propionate|potassium sorbate|sorbic acid|salt|wheat starch|natural|artificial flavors|wheat gluten|citric acid|annatto extract|cellulose gum|dextrin|guar gum|karaya gum|maltodextrin|mono|diglycerides|soy lecithin|tapioca starch|turmeric extract|wheat germ
# ---
# 483
# ---
# granola|whole grain oats|sugar|palm kernel|soybean oils|corn syrup|coconut|honey|molasses|soy lecithin|salt|corn starch|peanuts|almonds|soy flour|egg whites|corn syrup|chocolate chips|sugar|chocolate|cocoa butter|dextrose|soy lecithin|vanilla|milk|crisp rice|rice flour|sugar|whey|salt|barley malt|wheat flour|dextrose|palm kernel|soybean oils|water|sorbitol|nonfat dry milk|soy lecithin|salt|sugar|carrageenan
# ---
# 484
# ---
# flor de calabaza|agua|sal yodada y ácido cítrico
# ---
# 485
# ---
# espárragos blancos|agua|sal yodada y ácido cítrico
# ---
# 486
# ---
# elotitos tiernos|agua|sal yodada y ácido cítrico
# ---
# 487
# ---
# elotitos tiernos|agua|sal yodada y ácido cítrico
# ---
# 488
# ---
# pepino|agua|sal|ácido acético|cloruro de calcio|menos de|de benzoato de sodio|sorbato de potasio|amarillo|turmérico|saborizantes naturales
# ---
# 489
# ---
# palmitos|agua|sal y ácido cítrico
# ---
# 490
# ---
# es tomate deshidratado|aceite vegetal|sal|especias|laurel|orégano|ajo y cebolla
# ---
# 491
# ---
# arroz basmati
# ---
# 492
# ---
# arroz arborio
# ---
# 493
# ---
# arroz parboild precocido y arroz salvaje
# ---
# 494
# ---
# arroz parboiled de grano largo
# ---
# 495
# ---
# arroz jasmine
# ---
# 496
# ---
# contenido del empaque ramos es mayonesa|aceite de soya|yema de huevo|agua|vinagre de alcohol|azúcar|sal yodada|jugo de limón|especias y edta disódico|agua|aceite de canola|tomate deshidratado|pasta de tomate|azúcar|queso parmesano|cebolla en polvo|glutamato monosodico|acido acetico|ajo en polvo|cebolla granulada|perejil|goma xantana|oregano|acido ascorbiatico|jugo de limón en polvo|especias|laurel y pimienta negra
# ---
# 497
# ---
# chili|sugar|salt|garlic|distilled vinegar|potassium sorbate|sodium bisulfite as preservatives|and xanthan gum
# ---
# 498
# ---
# full fat soft goat's cheese made with pasteurised milk
# ---
# 499
# ---
# poitrine de poulet|ornions|tomates|huile de colza|pâte de tomate|vinaigre de vin blanc|piments rouges|mélasse yaourt faible en gras|lait|crème|lait|colorant|caramel|extrait de paprika|purée de gingembre|purée d'ail|piments verts|jus de citron coriandre moulue|maïzena|sel curcuma|graines de cumin|poivre noir moulu|fenugrec moulu|coriandre|garam masala|coriandre rôtie|cumin rôti|poivre noir|cannelle|macis|graines de cardamome vertes grillées|gingembre|fenouil|clous de girofle|feuilles de muscade|poudre de chili|paprika fumé moulu|paprika moulu|extrait de piment

# %% [markdown]
# ### Export the data to new CSV file

# %%
# # compression_opts = dict(method='zip', archive_name='products.csv')
# # data_products.to_csv('out_products.zip', index=False, compression=compression_opts, encoding='utf-8-sig')
# data_products.to_csv('products.csv', index=False, encoding='utf-8-sig')
data_products.head(100).to_csv('products_small.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Create categories dataset

# %%
allCategoriesTags = []
allCategoriesEn = [] 
for index, row in data_products.iterrows():
    categories_tags = row['categories_tags'].split("|")
    categories_en = row['categories_en'].split("|")
    for index, category_tag in enumerate(categories_tags):
        allCategoriesTags.append(category_tag)
        allCategoriesEn.append(categories_en[index])

len(allCategoriesTags)
len(allCategoriesEn)
# Out:
# 424881

# %%
data_categories = pd.DataFrame(
    {'tag': allCategoriesTags,
     'label': allCategoriesEn
    })
data_categories = data_categories.drop_duplicates(['tag'])
data_categories.sort_values(by=['tag'])
# Out:
#                        tag               label
# 11512   100-kokosnootwater  100-kokosnootwater
# 77613          100-legumes         100-legumes
# 194205          100-muscle          100-muscle
# 377862            107-kcal            107-kcal
# 7436                   110                 110
# ...                    ...                 ...
# 300010              チョコレート              チョコレート
# 299833                  飲品                  飲品
# 413435                  과자                  과자
# 413394                 씨리얼                 씨리얼
# 413386                   햄                   햄
#
# [10537 rows x 2 columns]

# %%
data_categories.to_csv('categories.csv', index=True, index_label="index", encoding='utf-8')

# %% [markdown]
# ### Create ingredients dataset (before formatting ingredients for products)

# %%
allIngredients = [] 
for index, text in enumerate(data_products['ingredients_text']):
    ingredients = text.split("|")
    for ingredient in ingredients:
        if(ingredient != '') : allIngredients.append(ingredient)

# %%
len(allIngredients)
# Out:
# 971352

# %%
# DISTINCT
allIngredients = list(set(allIngredients))
print(len(allIngredients))
# ABC SORT
allIngredients = sorted(allIngredients, key=str.lower)
# Out:
# 125130

# %%
data_ingredients = pd.DataFrame(data=allIngredients, columns=['id'])

# %%
data_ingredients['label'] = allIngredients

# %%
i = 0
iStop = iStop
while i < iStop:
    print("---")
    print(i)
    print("---")
    print(data_ingredients.iloc[i])
    i += 1
# Out:
# ---
# 0
# ---
# id       a a
# label    a a
# Name: 0, dtype: object
# ---
# 1
# ---
# id       a a cuc
# label    a a cuc
# Name: 1, dtype: object
# ---
# 2
# ---
# id       a acido citrico
# label    a acido citrico
# Name: 2, dtype: object
# ---
# 3
# ---
# id       a appellation d'origine protégée
# label    a appellation d'origine protégée
# Name: 3, dtype: object
# ---
# 4
# ---
# id       a appellation d'origine protégée produit élabo...
# label    a appellation d'origine protégée produit élabo...
# Name: 4, dtype: object
# ---
# 5
# ---
# id       a appellation d'origine protégée soit
# label    a appellation d'origine protégée soit
# Name: 5, dtype: object
# ---
# 6
# ---
# id       a around allspice
# label    a around allspice
# Name: 6, dtype: object
# ---
# 7
# ---
# id       a arroz extruído
# label    a arroz extruído
# Name: 7, dtype: object
# ---
# 8
# ---
# id       a atiuta sititior ains
# label    a atiuta sititior ains
# Name: 8, dtype: object
# ---
# 9
# ---
# id       a b vitamin
# label    a b vitamin
# Name: 9, dtype: object
# ---
# 10
# ---
# id       a bar for people with increased protein demands
# label    a bar for people with increased protein demands
# Name: 10, dtype: object
# ---
# 11
# ---
# id       a base de concentré
# label    a base de concentré
# Name: 11, dtype: object
# ---
# 12
# ---
# id       a blend of russet
# label    a blend of russet
# Name: 12, dtype: object
# ---
# 13
# ---
# id       a boire frais
# label    a boire frais
# Name: 13, dtype: object
# ---
# 14
# ---
# id       a braadcrumb
# label    a braadcrumb
# Name: 14, dtype: object
# ---
# 15
# ---
# id       a c
# label    a c
# Name: 15, dtype: object
# ---
# 16
# ---
# id       a ca kugợeln
# label    a ca kugợeln
# Name: 16, dtype: object
# ---
# 17
# ---
# id       a canne liquide bio
# label    a canne liquide bio
# Name: 17, dtype: object
# ---
# 18
# ---
# id       a chili
# label    a chili
# Name: 18, dtype: object
# ---
# 19
# ---
# id       a cocoo
# label    a cocoo
# Name: 19, dtype: object
# ---
# 20
# ---
# id       a code citrique
# label    a code citrique
# Name: 20, dtype: object
# ---
# 21
# ---
# id       a collaboration entre u et les ev
# label    a collaboration entre u et les ev
# Name: 21, dtype: object
# ---
# 22
# ---
# id       a concentrado vegetal
# label    a concentrado vegetal
# Name: 22, dtype: object
# ---
# 23
# ---
# id       a consc préférence avant le
# label    a consc préférence avant le
# Name: 23, dtype: object
# ---
# 24
# ---
# id       a conserver
# label    a conserver
# Name: 24, dtype: object
# ---
# 25
# ---
# id       a conserver au froid
# label    a conserver au froid
# Name: 25, dtype: object
# ---
# 26
# ---
# id       a conserver c
# label    a conserver c
# Name: 26, dtype: object
# ---
# 27
# ---
# id       a conserver dans son emballage femé
# label    a conserver dans son emballage femé
# Name: 27, dtype: object
# ---
# 28
# ---
# id       a conserver dans un endroit frais
# label    a conserver dans un endroit frais
# Name: 28, dtype: object
# ---
# 29
# ---
# id       a conserver en lieu frais et sec
# label    a conserver en lieu frais et sec
# Name: 29, dtype: object
# ---
# 30
# ---
# id       a conserver entre 'c e
# label    a conserver entre 'c e
# Name: 30, dtype: object
# ---
# 31
# ---
# id       a conserver entre c et
# label    a conserver entre c et
# Name: 31, dtype: object
# ---
# 32
# ---
# id       a conserver entre c et c
# label    a conserver entre c et c
# Name: 32, dtype: object
# ---
# 33
# ---
# id       a conserver entre et
# label    a conserver entre et
# Name: 33, dtype: object
# ---
# 34
# ---
# id       a conserver entre et maximum
# label    a conserver entre et maximum
# Name: 34, dtype: object
# ---
# 35
# ---
# id       a conserver entre et maximum a consommer ropid...
# label    a conserver entre et maximum a consommer ropid...
# Name: 35, dtype: object
# ---
# 36
# ---
# id       a conserver entre ooc et
# label    a conserver entre ooc et
# Name: 36, dtype: object
# ---
# 37
# ---
# id       a conserver entre préférence
# label    a conserver entre préférence
# Name: 37, dtype: object
# ---
# 38
# ---
# id       a conserver hors du informations réfrigérateur
# label    a conserver hors du informations réfrigérateur
# Name: 38, dtype: object
# ---
# 39
# ---
# id       a conserver ou sec et a labri de la chaleur
# label    a conserver ou sec et a labri de la chaleur
# Name: 39, dtype: object
# ---
# 40
# ---
# id       a conserver specially packed for
# label    a conserver specially packed for
# Name: 40, dtype: object
# ---
# 41
# ---
# id       a conserver à l'abri de la chaleur et de l'hum...
# label    a conserver à l'abri de la chaleur et de l'hum...
# Name: 41, dtype: object
# ---
# 42
# ---
# id       a conserver à l'abri de la chaleur et de met c...
# label    a conserver à l'abri de la chaleur et de met c...
# Name: 42, dtype: object
# ---
# 43
# ---
# id       a conserver à température ambiante
# label    a conserver à température ambiante
# Name: 43, dtype: object
# ---
# 44
# ---
# id       a consmerau réfrigérateur et consommer dans le...
# label    a consmerau réfrigérateur et consommer dans le...
# Name: 44, dtype: object
# ---
# 45
# ---
# id       a consommer ava voir l'emballage
# label    a consommer ava voir l'emballage
# Name: 45, dtype: object
# ---
# 46
# ---
# id       a consommer avant
# label    a consommer avant
# Name: 46, dtype: object
# ---
# 47
# ---
# id       a consommer avant voir sur le couvercle
# label    a consommer avant voir sur le couvercle
# Name: 47, dtype: object
# ---
# 48
# ---
# id       a consommer avec modération
# label    a consommer avec modération
# Name: 48, dtype: object
# ---
# 49
# ---
# id       a consommer couchon
# label    a consommer couchon
# Name: 49, dtype: object
# ---
# 50
# ---
# id       a consommer de avant f
# label    a consommer de avant f
# Name: 50, dtype: object
# ---
# 51
# ---
# id       a consommer de ca preference avant voir capsule
# label    a consommer de ca preference avant voir capsule
# Name: 51, dtype: object
# ---
# 52
# ---
# id       a consommer de preference avant le n de lot
# label    a consommer de preference avant le n de lot
# Name: 52, dtype: object
# ---
# 53
# ---
# id       a consommer de preference avant le vorsul cteille
# label    a consommer de preference avant le vorsul cteille
# Name: 53, dtype: object
# ---
# 54
# ---
# id       a consommer de préference ava voir sur l'embal...
# label    a consommer de préference ava voir sur l'embal...
# Name: 54, dtype: object
# ---
# 55
# ---
# id       a consommer de préférence avant f voir sur le ...
# label    a consommer de préférence avant f voir sur le ...
# Name: 55, dtype: object
# ---
# 56
# ---
# id       a consommer de préférence avant la date imprim...
# label    a consommer de préférence avant la date imprim...
# Name: 56, dtype: object
# ---
# 57
# ---
# id       a consommer de préférence avant le
# label    a consommer de préférence avant le
# Name: 57, dtype: object
# ---
# 58
# ---
# id       a consommer de préférence avant voir au dos
# label    a consommer de préférence avant voir au dos
# Name: 58, dtype: object
# ---
# 59
# ---
# id       a consommer de t n
# label    a consommer de t n
# Name: 59, dtype: object
# ---
# 60
# ---
# id       a consommer en l'état
# label    a consommer en l'état
# Name: 60, dtype: object
# ---
# 61
# ---
# id       a consommer et no de lot
# label    a consommer et no de lot
# Name: 61, dtype: object
# ---
# 62
# ---
# id       a consommer immédiatement
# label    a consommer immédiatement
# Name: 62, dtype: object
# ---
# 63
# ---
# id       a consommer immédiatement opres ouverture te g...
# label    a consommer immédiatement opres ouverture te g...
# Name: 63, dtype: object
# ---
# 64
# ---
# id       a consommer jusau'au
# label    a consommer jusau'au
# Name: 64, dtype: object
# ---
# 65
# ---
# id       a consommer jusqu'au
# label    a consommer jusqu'au
# Name: 65, dtype: object
# ---
# 66
# ---
# id       a consommer rapidement
# label    a consommer rapidement
# Name: 66, dtype: object
# ---
# 67
# ---
# id       a consommerjusqu'au
# label    a consommerjusqu'au
# Name: 67, dtype: object
# ---
# 68
# ---
# id       a consommmer cuit a coeur
# label    a consommmer cuit a coeur
# Name: 68, dtype: object
# ---
# 69
# ---
# id       a consonner jusqu aus
# label    a consonner jusqu aus
# Name: 69, dtype: object
# ---
# 70
# ---
# id       a consover entre et
# label    a consover entre et
# Name: 70, dtype: object
# ---
# 71
# ---
# id       a contains
# label    a contains
# Name: 71, dtype: object
# ---
# 72
# ---
# id       a contrada costaralla
# label    a contrada costaralla
# Name: 72, dtype: object
# ---
# 73
# ---
# id       a crema puede contensoya
# label    a crema puede contensoya
# Name: 73, dtype: object
# ---
# 74
# ---
# id       a crushed kiwi
# label    a crushed kiwi
# Name: 74, dtype: object
# ---
# 75
# ---
# id       a csokoládé kakaószárazanyagtartalma legalább
# label    a csokoládé kakaószárazanyagtartalma legalább
# Name: 75, dtype: object
# ---
# 76
# ---
# id       a cukier lub b syrop fruktozowoglukozowy
# label    a cukier lub b syrop fruktozowoglukozowy
# Name: 76, dtype: object
# ---
# 77
# ---
# id       a cukier lub b syrop glukozowofruktozowy
# label    a cukier lub b syrop glukozowofruktozowy
# Name: 77, dtype: object
# ---
# 78
# ---
# id       a césulfamek
# label    a césulfamek
# Name: 78, dtype: object
# ---
# 79
# ---
# id       a dash of baobab extradt
# label    a dash of baobab extradt
# Name: 79, dtype: object
# ---
# 80
# ---
# id       a dash of beetroot juice
# label    a dash of beetroot juice
# Name: 80, dtype: object
# ---
# 81
# ---
# id       a dash of guarana infusion
# label    a dash of guarana infusion
# Name: 81, dtype: object
# ---
# 82
# ---
# id       a dash of lime juice
# label    a dash of lime juice
# Name: 82, dtype: object
# ---
# 83
# ---
# id       a dash of spinach
# label    a dash of spinach
# Name: 83, dtype: object
# ---
# 84
# ---
# id       a de c
# label    a de c
# Name: 84, dtype: object
# ---
# 85
# ---
# id       a de cv
# label    a de cv
# Name: 85, dtype: object
# ---
# 86
# ---
# id       a deshydraté
# label    a deshydraté
# Name: 86, dtype: object
# ---
# 87
# ---
# id       a deshydratés
# label    a deshydratés
# Name: 87, dtype: object
# ---
# 88
# ---
# id       a diluer aan te lengen ww al
# label    a diluer aan te lengen ww al
# Name: 88, dtype: object
# ---
# 89
# ---
# id       a distributed p
# label    a distributed p
# Name: 89, dtype: object
# ---
# 90
# ---
# id       a division of
# label    a division of
# Name: 90, dtype: object
# ---
# 91
# ---
# id       a doboz tetején feltűntetett időpontig
# label    a doboz tetején feltűntetett időpontig
# Name: 91, dtype: object
# ---
# 92
# ---
# id       a déguster froid en salade ou avec une tranche...
# label    a déguster froid en salade ou avec une tranche...
# Name: 92, dtype: object
# ---
# 93
# ---
# id       a e
# label    a e
# Name: 93, dtype: object
# ---
# 94
# ---
# id       a embalagem de contém cerca de
# label    a embalagem de contém cerca de
# Name: 94, dtype: object
# ---
# 95
# ---
# id       a et c
# label    a et c
# Name: 95, dtype: object
# ---
# 96
# ---
# id       a evegetal le na de soya
# label    a evegetal le na de soya
# Name: 96, dtype: object
# ---
# 97
# ---
# id       a harina de trigo
# label    a harina de trigo
# Name: 97, dtype: object
# ---
# 98
# ---
# id       a healthy lifestyle
# label    a healthy lifestyle
# Name: 98, dtype: object
# ---
# 99
# ---
# id       a healthy lifestyle is recommended for good he...
# label    a healthy lifestyle is recommended for good he...
# Name: 99, dtype: object
# ---
# 100
# ---
# id       a hint of natural flavouring
# label    a hint of natural flavouring
# Name: 100, dtype: object
# ---
# 101
# ---
# id       a hint of natural flavourings
# label    a hint of natural flavourings
# Name: 101, dtype: object
# ---
# 102
# ---
# id       a i d
# label    a i d
# Name: 102, dtype: object
# ---
# 103
# ---
# id       a i de chateur
# label    a i de chateur
# Name: 103, dtype: object
# ---
# 104
# ---
# id       a ieoo
# label    a ieoo
# Name: 104, dtype: object
# ---
# 105
# ---
# id       a isomaltulose é uma fornte de glucose e frutose
# label    a isomaltulose é uma fornte de glucose e frutose
# Name: 105, dtype: object
# ---
# 106
# ---
# id       a j prepared in an area which uses nuts
# label    a j prepared in an area which uses nuts
# Name: 106, dtype: object
# ---
# 107
# ---
# id       a ja dvitamiini
# label    a ja dvitamiini
# Name: 107, dtype: object
# ---
# 108
# ---
# id       a ja itamiini
# label    a ja itamiini
# Name: 108, dtype: object
# ---
# 109
# ---
# id       a johannisbrotkernmehl
# label    a johannisbrotkernmehl
# Name: 109, dtype: object
# ---
# 110
# ---
# id       a koncentrat pomidorowy
# label    a koncentrat pomidorowy
# Name: 110, dtype: object
# ---
# 111
# ---
# id       a l'abri de la lumière du soleil
# label    a l'abri de la lumière du soleil
# Name: 111, dtype: object
# ---
# 112
# ---
# id       a la crème
# label    a la crème
# Name: 112, dtype: object
# ---
# 113
# ---
# id       a lifestyle
# label    a lifestyle
# Name: 113, dtype: object
# ---
# 114
# ---
# id       a lub b
# label    a lub b
# Name: 114, dtype: object
# ---
# 115
# ---
# id       a malico estearato de calcio
# label    a malico estearato de calcio
# Name: 115, dtype: object
# ---
# 116
# ---
# id       a manueactured n bouudupnr
# label    a manueactured n bouudupnr
# Name: 116, dtype: object
# ---
# 117
# ---
# id       a mashed banana
# label    a mashed banana
# Name: 117, dtype: object
# ---
# 118
# ---
# id       a may be prese fish
# label    a may be prese fish
# Name: 118, dtype: object
# ---
# 119
# ---
# id       a metabisulfito de sodio
# label    a metabisulfito de sodio
# Name: 119, dtype: object
# ---
# 120
# ---
# id       a milk
# label    a milk
# Name: 120, dtype: object
# ---
# 121
# ---
# id       a milk derivative
# label    a milk derivative
# Name: 121, dtype: object
# ---
# 122
# ---
# id       a mold inhibitor
# label    a mold inhibitor
# Name: 122, dtype: object
# ---
# 123
# ---
# id       a n
# label    a n
# Name: 123, dtype: object
# ---
# 124
# ---
# id       a n de a
# label    a n de a
# Name: 124, dtype: object
# ---
# 125
# ---
# id       a natural mold inhibitor
# label    a natural mold inhibitor
# Name: 125, dtype: object
# ---
# 126
# ---
# id       a naturally occurring mineral
# label    a naturally occurring mineral
# Name: 126, dtype: object
# ---
# 127
# ---
# id       a notre cons a déguster frais sur une tranche ...
# label    a notre cons a déguster frais sur une tranche ...
# Name: 127, dtype: object
# ---
# 128
# ---
# id       a nu se recongela dupa decongelare
# label    a nu se recongela dupa decongelare
# Name: 128, dtype: object
# ---
# 129
# ---
# id       a nugnenwnssuaunbd zsm au ouro mel pepao inc n...
# label    a nugnenwnssuaunbd zsm au ouro mel pepao inc n...
# Name: 129, dtype: object
# ---
# 130
# ---
# id       a o
# label    a o
# Name: 130, dtype: object
# ---
# 131
# ---
# id       a o international pap
# label    a o international pap
# Name: 131, dtype: object
# ---
# 132
# ---
# id       a och dvitamin
# label    a och dvitamin
# Name: 132, dtype: object
# ---
# 133
# ---
# id       a och itamin
# label    a och itamin
# Name: 133, dtype: object
# ---
# 134
# ---
# id       a ou b voir le dessous de la boîte
# label    a ou b voir le dessous de la boîte
# Name: 134, dtype: object
# ---
# 135
# ---
# id       a ou b voir le fond de la boîte
# label    a ou b voir le fond de la boîte
# Name: 135, dtype: object
# ---
# 136
# ---
# id       a p
# label    a p
# Name: 136, dtype: object
# ---
# 137
# ---
# id       a paprika
# label    a paprika
# Name: 137, dtype: object
# ---
# 138
# ---
# id       a partir de concentrado
# label    a partir de concentrado
# Name: 138, dtype: object
# ---
# 139
# ---
# id       a partir de concentrados
# label    a partir de concentrados
# Name: 139, dtype: object
# ---
# 140
# ---
# id       a partir de los etapa sin azucar añadida
# label    a partir de los etapa sin azucar añadida
# Name: 140, dtype: object
# ---
# 141
# ---
# id       a pasta de avellana
# label    a pasta de avellana
# Name: 141, dtype: object
# ---
# 142
# ---
# id       a pectina
# label    a pectina
# Name: 142, dtype: object
# ---
# 143
# ---
# id       a permitted artificial coloring
# label    a permitted artificial coloring
# Name: 143, dtype: object
# ---
# 144
# ---
# id       a permitted raising agents
# label    a permitted raising agents
# Name: 144, dtype: object
# ---
# 145
# ---
# id       a pomelo
# label    a pomelo
# Name: 145, dtype: object
# ---
# 146
# ---
# id       a pr
# label    a pr
# Name: 146, dtype: object
# ---
# 147
# ---
# id       a praskajícími kuličkami
# label    a praskajícími kuličkami
# Name: 147, dtype: object
# ---
# 148
# ---
# id       a preservative
# label    a preservative
# Name: 148, dtype: object
# ---
# 149
# ---
# id       a prika
# label    a prika
# Name: 149, dtype: object
# ---
# 150
# ---
# id       a purée de fruits ns colorant artificiel au ju...
# label    a purée de fruits ns colorant artificiel au ju...
# Name: 150, dtype: object
# ---
# 151
# ---
# id       a roche leclerc rte normand
# label    a roche leclerc rte normand
# Name: 151, dtype: object
# ---
# 152
# ---
# id       a rtensia rx wwiveriw novporama r
# label    a rtensia rx wwiveriw novporama r
# Name: 152, dtype: object
# ---
# 153
# ---
# id       a réfrigerer
# label    a réfrigerer
# Name: 153, dtype: object
# ---
# 154
# ---
# id       a saborizantes aruficiales
# label    a saborizantes aruficiales
# Name: 154, dtype: object
# ---
# 155
# ---
# id       a se consuma
# label    a se consuma
# Name: 155, dtype: object
# ---
# 156
# ---
# id       a se consuma de preferință înainte de sfârşit ...
# label    a se consuma de preferință înainte de sfârşit ...
# Name: 156, dtype: object
# ---
# 157
# ---
# id       a se consuma imediat după deschidere
# label    a se consuma imediat după deschidere
# Name: 157, dtype: object
# ---
# 158
# ---
# id       a se consuma inainte vezi ambalaj
# label    a se consuma inainte vezi ambalaj
# Name: 158, dtype: object
# ---
# 159
# ---
# id       a se consuma inainte vezi dataşinumanul lotulu...
# label    a se consuma inainte vezi dataşinumanul lotulu...
# Name: 159, dtype: object
# ---
# 160
# ---
# id       a se pastra la
# label    a se pastra la
# Name: 160, dtype: object
# ---
# 161
# ---
# id       a se păstra la loc uscat și răcoros
# label    a se păstra la loc uscat și răcoros
# Name: 161, dtype: object
# ---
# 162
# ---
# id       a se păstra în loc uscat şi ferit de lumina so...
# label    a se păstra în loc uscat şi ferit de lumina so...
# Name: 162, dtype: object
# ---
# 163
# ---
# id       a se păstra în loc uscat şi răcoros
# label    a se păstra în loc uscat şi răcoros
# Name: 163, dtype: object
# ---
# 164
# ---
# id       a se păstra în încăperi curate
# label    a se păstra în încăperi curate
# Name: 164, dtype: object
# ---
# 165
# ---
# id       a senf
# label    a senf
# Name: 165, dtype: object
# ---
# 166
# ---
# id       a sirop de glucosefructose
# label    a sirop de glucosefructose
# Name: 166, dtype: object
# ---
# 167
# ---
# id       a sous zones mer de barrents
# label    a sous zones mer de barrents
# Name: 167, dtype: object
# ---
# 168
# ---
# id       a squeeze of beetroot
# label    a squeeze of beetroot
# Name: 168, dtype: object
# ---
# 169
# ---
# id       a sáb
# label    a sáb
# Name: 169, dtype: object
# ---
# 170
# ---
# id       a tamaras tra amaras
# label    a tamaras tra amaras
# Name: 170, dtype: object
# ---
# 171
# ---
# id       a termék glutént
# label    a termék glutént
# Name: 171, dtype: object
# ---
# 172
# ---
# id       a termék szóját
# label    a termék szóját
# Name: 172, dtype: object
# ---
# 173
# ---
# id       a termék szóját és dióféléket
# label    a termék szóját és dióféléket
# Name: 173, dtype: object
# ---
# 174
# ---
# id       a töltelékben
# label    a töltelékben
# Name: 174, dtype: object
# ---
# 175
# ---
# id       a utiliser à l'apéritif en accompagnement de b...
# label    a utiliser à l'apéritif en accompagnement de b...
# Name: 175, dtype: object
# ---
# 176
# ---
# id       a van verzadigde vetzuren
# label    a van verzadigde vetzuren
# Name: 176, dtype: object
# ---
# 177
# ---
# id       a varied
# label    a varied
# Name: 177, dtype: object
# ---
# 178
# ---
# id       a vegetal
# label    a vegetal
# Name: 178, dtype: object
# ---
# 179
# ---
# id       a vendre jusqu'au l
# label    a vendre jusqu'au l
# Name: 179, dtype: object
# ---
# 180
# ---
# id       a wnsommer
# label    a wnsommer
# Name: 180, dtype: object
# ---
# 181
# ---
# id       a www
# label    a www
# Name: 181, dtype: object
# ---
# 182
# ---
# id       a y d
# label    a y d
# Name: 182, dtype: object
# ---
# 183
# ---
# id       a zoetstoff acesulfaamk
# label    a zoetstoff acesulfaamk
# Name: 183, dtype: object
# ---
# 184
# ---
# id       a și d
# label    a și d
# Name: 184, dtype: object
# ---
# 185
# ---
# id       a ข coconut
# label    a ข coconut
# Name: 185, dtype: object
# ---
# 186
# ---
# id       a สิ
# label    a สิ
# Name: 186, dtype: object
# ---
# 187
# ---
# id       a ส่มนประกอบที่ส่าคัญโดย
# label    a ส่มนประกอบที่ส่าคัญโดย
# Name: 187, dtype: object
# ---
# 188
# ---
# id       aaannsuamsuiuanau auannunnuu
# label    aaannsuamsuiuanau auannunnuu
# Name: 188, dtype: object
# ---
# 189
# ---
# id       aabinst
# label    aabinst
# Name: 189, dtype: object
# ---
# 190
# ---
# id       aaci
# label    aaci
# Name: 190, dtype: object
# ---
# 191
# ---
# id       aaesiins
# label    aaesiins
# Name: 191, dtype: object
# ---
# 192
# ---
# id       aainanriiu
# label    aainanriiu
# Name: 192, dtype: object
# ---
# 193
# ---
# id       aaiuntautelenu
# label    aaiuntautelenu
# Name: 193, dtype: object
# ---
# 194
# ---
# id       aajunsns
# label    aajunsns
# Name: 194, dtype: object
# ---
# 195
# ---
# id       aakes
# label    aakes
# Name: 195, dtype: object
# ---
# 196
# ---
# id       aamylase
# label    aamylase
# Name: 196, dtype: object
# ---
# 197
# ---
# id       aamylase xylanase
# label    aamylase xylanase
# Name: 197, dtype: object
# ---
# 198
# ---
# id       aan
# label    aan
# Name: 198, dtype: object
# ---
# 199
# ---
# id       aanousnywertabulsnouva
# label    aanousnywertabulsnouva
# Name: 199, dtype: object
# ---
# 200
# ---
# id       aansins
# label    aansins
# Name: 200, dtype: object
# ---
# 201
# ---
# id       aaoiastri
# label    aaoiastri
# Name: 201, dtype: object
# ---
# 202
# ---
# id       aaoinas
# label    aaoinas
# Name: 202, dtype: object
# ---
# 203
# ---
# id       aar
# label    aar
# Name: 203, dtype: object
# ---
# 204
# ---
# id       aarbei
# label    aarbei
# Name: 204, dtype: object
# ---
# 205
# ---
# id       aard appel maltodextrine
# label    aard appel maltodextrine
# Name: 205, dtype: object
# ---
# 206
# ---
# id       aardappel
# label    aardappel
# Name: 206, dtype: object
# ---
# 207
# ---
# id       aardappeleiwit
# label    aardappeleiwit
# Name: 207, dtype: object
# ---
# 208
# ---
# id       aardappelen
# label    aardappelen
# Name: 208, dtype: object
# ---
# 209
# ---
# id       aardappelmeel
# label    aardappelmeel
# Name: 209, dtype: object
# ---
# 210
# ---
# id       aardappelpoeder
# label    aardappelpoeder
# Name: 210, dtype: object
# ---
# 211
# ---
# id       aardappelpuree
# label    aardappelpuree
# Name: 211, dtype: object
# ---
# 212
# ---
# id       aardappelvezel
# label    aardappelvezel
# Name: 212, dtype: object
# ---
# 213
# ---
# id       aardappelvezels
# label    aardappelvezels
# Name: 213, dtype: object
# ---
# 214
# ---
# id       aardappelvlokken
# label    aardappelvlokken
# Name: 214, dtype: object
# ---
# 215
# ---
# id       aardappelzetmeel
# label    aardappelzetmeel
# Name: 215, dtype: object
# ---
# 216
# ---
# id       aardbei
# label    aardbei
# Name: 216, dtype: object
# ---
# 217
# ---
# id       aardbeiconcentraat
# label    aardbeiconcentraat
# Name: 217, dtype: object
# ---
# 218
# ---
# id       aardbeien
# label    aardbeien
# Name: 218, dtype: object
# ---
# 219
# ---
# id       aardbeienbereiding
# label    aardbeienbereiding
# Name: 219, dtype: object
# ---
# 220
# ---
# id       aardbeienpuree
# label    aardbeienpuree
# Name: 220, dtype: object
# ---
# 221
# ---
# id       aardbeiensap
# label    aardbeiensap
# Name: 221, dtype: object
# ---
# 222
# ---
# id       aardbeienvulling
# label    aardbeienvulling
# Name: 222, dtype: object
# ---
# 223
# ---
# id       aasspsa
# label    aasspsa
# Name: 223, dtype: object
# ---
# 224
# ---
# id       aata
# label    aata
# Name: 224, dtype: object
# ---
# 225
# ---
# id       aau
# label    aau
# Name: 225, dtype: object
# ---
# 226
# ---
# id       aaucionn
# label    aaucionn
# Name: 226, dtype: object
# ---
# 227
# ---
# id       aauiast
# label    aauiast
# Name: 227, dtype: object
# ---
# 228
# ---
# id       aaujsnlasn
# label    aaujsnlasn
# Name: 228, dtype: object
# ---
# 229
# ---
# id       aawsn
# label    aawsn
# Name: 229, dtype: object
# ---
# 230
# ---
# id       aaρn
# label    aaρn
# Name: 230, dtype: object
# ---
# 231
# ---
# id       abadejo de alaska y
# label    abadejo de alaska y
# Name: 231, dtype: object
# ---
# 232
# ---
# id       abani harina de trigo
# label    abani harina de trigo
# Name: 232, dtype: object
# ---
# 233
# ---
# id       abat de porc
# label    abat de porc
# Name: 233, dtype: object
# ---
# 234
# ---
# id       abats
# label    abats
# Name: 234, dtype: object
# ---
# 235
# ---
# id       abats de boeuf
# label    abats de boeuf
# Name: 235, dtype: object
# ---
# 236
# ---
# id       abats de porc
# label    abats de porc
# Name: 236, dtype: object
# ---
# 237
# ---
# id       abats de porc précuits
# label    abats de porc précuits
# Name: 237, dtype: object
# ---
# 238
# ---
# id       abattu en france
# label    abattu en france
# Name: 238, dtype: object
# ---
# 239
# ---
# id       abattu et transformé en france
# label    abattu et transformé en france
# Name: 239, dtype: object
# ---
# 240
# ---
# id       abattu et élaboré en france
# label    abattu et élaboré en france
# Name: 240, dtype: object
# ---
# 241
# ---
# id       abattus en allemagne
# label    abattus en allemagne
# Name: 241, dtype: object
# ---
# 242
# ---
# id       abattus en france
# label    abattus en france
# Name: 242, dtype: object
# ---
# 243
# ---
# id       abattus en thaïlande
# label    abattus en thaïlande
# Name: 243, dtype: object
# ---
# 244
# ---
# id       abattus et transformés en france
# label    abattus et transformés en france
# Name: 244, dtype: object
# ---
# 245
# ---
# id       abattus et transformés en thailande
# label    abattus et transformés en thailande
# Name: 245, dtype: object
# ---
# 246
# ---
# id       abeille
# label    abeille
# Name: 246, dtype: object
# ---
# 247
# ---
# id       abeille blanche et jaune
# label    abeille blanche et jaune
# Name: 247, dtype: object
# ---
# 248
# ---
# id       abeille cire de carnauba shellac
# label    abeille cire de carnauba shellac
# Name: 248, dtype: object
# ---
# 249
# ---
# id       abelmoschus esculentus
# label    abelmoschus esculentus
# Name: 249, dtype: object
# ---
# 250
# ---
# id       aberdeen angus beef powder
# label    aberdeen angus beef powder
# Name: 250, dtype: object
# ---
# 251
# ---
# id       abgepackt in den niederlanden
# label    abgepackt in den niederlanden
# Name: 251, dtype: object
# ---
# 252
# ---
# id       abies balsamea
# label    abies balsamea
# Name: 252, dtype: object
# ---
# 253
# ---
# id       abins
# label    abins
# Name: 253, dtype: object
# ---
# 254
# ---
# id       abizer ใช้ไคโซเคียมรไรโบนิวคลีโอไทค์ เป็นวัคถุ...
# label    abizer ใช้ไคโซเคียมรไรโบนิวคลีโอไทค์ เป็นวัคถุ...
# Name: 254, dtype: object
# ---
# 255
# ---
# id       ables fourrage
# label    ables fourrage
# Name: 255, dtype: object
# ---
# 256
# ---
# id       ablwidds
# label    ablwidds
# Name: 256, dtype: object
# ---
# 257
# ---
# id       abohnen
# label    abohnen
# Name: 257, dtype: object
# ---
# 258
# ---
# id       abondance
# label    abondance
# Name: 258, dtype: object
# ---
# 259
# ---
# id       abondance aop
# label    abondance aop
# Name: 259, dtype: object
# ---
# 260
# ---
# id       aborizante artificial y colorante natural
# label    aborizante artificial y colorante natural
# Name: 260, dtype: object
# ---
# 261
# ---
# id       abrico
# label    abrico
# Name: 261, dtype: object
# ---
# 262
# ---
# id       abricot
# label    abricot
# Name: 262, dtype: object
# ---
# 263
# ---
# id       abricot au sirop
# label    abricot au sirop
# Name: 263, dtype: object
# ---
# 264
# ---
# id       abricot bergeron
# label    abricot bergeron
# Name: 264, dtype: object
# ---
# 265
# ---
# id       abricot bio
# label    abricot bio
# Name: 265, dtype: object
# ---
# 266
# ---
# id       abricot biologique
# label    abricot biologique
# Name: 266, dtype: object
# ---
# 267
# ---
# id       abricot cerise
# label    abricot cerise
# Name: 267, dtype: object
# ---
# 268
# ---
# id       abricot de la vallée du rhône
# label    abricot de la vallée du rhône
# Name: 268, dtype: object
# ---
# 269
# ---
# id       abricot de provence
# label    abricot de provence
# Name: 269, dtype: object
# ---
# 270
# ---
# id       abricot deshydraté
# label    abricot deshydraté
# Name: 270, dtype: object
# ---
# 271
# ---
# id       abricot et goyave
# label    abricot et goyave
# Name: 271, dtype: object
# ---
# 272
# ---
# id       abricot et poire
# label    abricot et poire
# Name: 272, dtype: object
# ---
# 273
# ---
# id       abricot façon crumble
# label    abricot façon crumble
# Name: 273, dtype: object
# ---
# 274
# ---
# id       abricot française
# label    abricot française
# Name: 274, dtype: object
# ---
# 275
# ---
# id       abricot goyave
# label    abricot goyave
# Name: 275, dtype: object
# ---
# 276
# ---
# id       abricot mangue
# label    abricot mangue
# Name: 276, dtype: object
# ---
# 277
# ---
# id       abricot min
# label    abricot min
# Name: 277, dtype: object
# ---
# 278
# ---
# id       abricot mixé
# label    abricot mixé
# Name: 278, dtype: object
# ---
# 279
# ---
# id       abricot orangé de provence
# label    abricot orangé de provence
# Name: 279, dtype: object
# ---
# 280
# ---
# id       abricot ou ananas ou cerise ou figue ou fraise...
# label    abricot ou ananas ou cerise ou figue ou fraise...
# Name: 280, dtype: object
# ---
# 281
# ---
# id       abricot ou ananas ou pêche ou poire
# label    abricot ou ananas ou pêche ou poire
# Name: 281, dtype: object
# ---
# 282
# ---
# id       abricot ou cerise ou fraise
# label    abricot ou cerise ou fraise
# Name: 282, dtype: object
# ---
# 283
# ---
# id       abricot ou cerise ou fraise ou pêche
# label    abricot ou cerise ou fraise ou pêche
# Name: 283, dtype: object
# ---
# 284
# ---
# id       abricot ou fraise ou cerise ou pêche poudre de...
# label    abricot ou fraise ou cerise ou pêche poudre de...
# Name: 284, dtype: object
# ---
# 285
# ---
# id       abricot ou fraise ou framboise ou pêche ou cit...
# label    abricot ou fraise ou framboise ou pêche ou cit...
# Name: 285, dtype: object
# ---
# 286
# ---
# id       abricot ou fraise ou framboise ou pêche sucre
# label    abricot ou fraise ou framboise ou pêche sucre
# Name: 286, dtype: object
# ---
# 287
# ---
# id       abricot ou framboise
# label    abricot ou framboise
# Name: 287, dtype: object
# ---
# 288
# ---
# id       abricot ou poire ou ananas ou nectarine
# label    abricot ou poire ou ananas ou nectarine
# Name: 288, dtype: object
# ---
# 289
# ---
# id       abricot ou pêche
# label    abricot ou pêche
# Name: 289, dtype: object
# ---
# 290
# ---
# id       abricot ou pêche ou poire
# label    abricot ou pêche ou poire
# Name: 290, dtype: object
# ---
# 291
# ---
# id       abricot ou pêche ou poire ou pomme
# label    abricot ou pêche ou poire ou pomme
# Name: 291, dtype: object
# ---
# 292
# ---
# id       abricot sec
# label    abricot sec
# Name: 292, dtype: object
# ---
# 293
# ---
# id       abricot secs
# label    abricot secs
# Name: 293, dtype: object
# ---
# 294
# ---
# id       abricot semidéshydraté
# label    abricot semidéshydraté
# Name: 294, dtype: object
# ---
# 295
# ---
# id       abricot séché
# label    abricot séché
# Name: 295, dtype: object
# ---
# 296
# ---
# id       abricotine
# label    abricotine
# Name: 296, dtype: object
# ---
# 297
# ---
# id       abricots
# label    abricots
# Name: 297, dtype: object
# ---
# 298
# ---
# id       abricots bio
# label    abricots bio
# Name: 298, dtype: object
# ---
# 299
# ---
# id       abricots biologiques
# label    abricots biologiques
# Name: 299, dtype: object
# ---
# 300
# ---
# id       abricots biologiques may conta tree nuts
# label    abricots biologiques may conta tree nuts
# Name: 300, dtype: object
# ---
# 301
# ---
# id       abricots cubes
# label    abricots cubes
# Name: 301, dtype: object
# ---
# 302
# ---
# id       abricots d'occitanie
# label    abricots d'occitanie
# Name: 302, dtype: object
# ---
# 303
# ---
# id       abricots de provence
# label    abricots de provence
# Name: 303, dtype: object
# ---
# 304
# ---
# id       abricots du languedocroussillon
# label    abricots du languedocroussillon
# Name: 304, dtype: object
# ---
# 305
# ---
# id       abricots du roussillon
# label    abricots du roussillon
# Name: 305, dtype: object
# ---
# 306
# ---
# id       abricots déshydratés
# label    abricots déshydratés
# Name: 306, dtype: object
# ---
# 307
# ---
# id       abricots en cube
# label    abricots en cube
# Name: 307, dtype: object
# ---
# 308
# ---
# id       abricots en morceaux
# label    abricots en morceaux
# Name: 308, dtype: object
# ---
# 309
# ---
# id       abricots et purée d'abricots
# label    abricots et purée d'abricots
# Name: 309, dtype: object
# ---
# 310
# ---
# id       abricots farine de riz conservateur
# label    abricots farine de riz conservateur
# Name: 310, dtype: object
# ---
# 311
# ---
# id       abricots moelleux
# label    abricots moelleux
# Name: 311, dtype: object
# ---
# 312
# ---
# id       abricots ou fraise ou mangue
# label    abricots ou fraise ou mangue
# Name: 312, dtype: object
# ---
# 313
# ---
# id       abricots pelés
# label    abricots pelés
# Name: 313, dtype: object
# ---
# 314
# ---
# id       abricots rouges du roussillon
# label    abricots rouges du roussillon
# Name: 314, dtype: object
# ---
# 315
# ---
# id       abricots sec
# label    abricots sec
# Name: 315, dtype: object
# ---
# 316
# ---
# id       abricots secs
# label    abricots secs
# Name: 316, dtype: object
# ---
# 317
# ---
# id       abricots secs bio
# label    abricots secs bio
# Name: 317, dtype: object
# ---
# 318
# ---
# id       abricots secs biologiques
# label    abricots secs biologiques
# Name: 318, dtype: object
# ---
# 319
# ---
# id       abricots secs de turquie
# label    abricots secs de turquie
# Name: 319, dtype: object
# ---
# 320
# ---
# id       abricots secs de turquie dénoyautés
# label    abricots secs de turquie dénoyautés
# Name: 320, dtype: object
# ---
# 321
# ---
# id       abricots secs dénoyautés
# label    abricots secs dénoyautés
# Name: 321, dtype: object
# ---
# 322
# ---
# id       abricots secs entiers dénoyautés
# label    abricots secs entiers dénoyautés
# Name: 322, dtype: object
# ---
# 323
# ---
# id       abricots secs entiers dénoyautés de turquie
# label    abricots secs entiers dénoyautés de turquie
# Name: 323, dtype: object
# ---
# 324
# ---
# id       abricots secs entiers dénoyautés de turquie ea...
# label    abricots secs entiers dénoyautés de turquie ea...
# Name: 324, dtype: object
# ---
# 325
# ---
# id       abricots secs hachés
# label    abricots secs hachés
# Name: 325, dtype: object
# ---
# 326
# ---
# id       abricots secs réhydratés à
# label    abricots secs réhydratés à
# Name: 326, dtype: object
# ---
# 327
# ---
# id       abricots sirop de glucosefructose sucre
# label    abricots sirop de glucosefructose sucre
# Name: 327, dtype: object
# ---
# 328
# ---
# id       abricots séchés
# label    abricots séchés
# Name: 328, dtype: object
# ---
# 329
# ---
# id       abricots séchés réhydratés pasteurisés
# label    abricots séchés réhydratés pasteurisés
# Name: 329, dtype: object
# ---
# 330
# ---
# id       abrikozbinectar gedeeltelijuopmsis van vruchte...
# label    abrikozbinectar gedeeltelijuopmsis van vruchte...
# Name: 330, dtype: object
# ---
# 331
# ---
# id       abrikozen
# label    abrikozen
# Name: 331, dtype: object
# ---
# 332
# ---
# id       abrikozenpitten
# label    abrikozenpitten
# Name: 332, dtype: object
# ---
# 333
# ---
# id       abrillantador
# label    abrillantador
# Name: 333, dtype: object
# ---
# 334
# ---
# id       absence d'arachides
# label    absence d'arachides
# Name: 334, dtype: object
# ---
# 335
# ---
# id       absent bobodioulasso
# label    absent bobodioulasso
# Name: 335, dtype: object
# ---
# 336
# ---
# id       absheudnary
# label    absheudnary
# Name: 336, dtype: object
# ---
# 337
# ---
# id       absinthe
# label    absinthe
# Name: 337, dtype: object
# ---
# 338
# ---
# id       absorbic acid
# label    absorbic acid
# Name: 338, dtype: object
# ---
# 339
# ---
# id       abudceun
# label    abudceun
# Name: 339, dtype: object
# ---
# 340
# ---
# id       abudn anln
# label    abudn anln
# Name: 340, dtype: object
# ---
# 341
# ---
# id       abuds neu lansanlnica
# label    abuds neu lansanlnica
# Name: 341, dtype: object
# ---
# 342
# ---
# id       abudsnauanainylausu trolwn
# label    abudsnauanainylausu trolwn
# Name: 342, dtype: object
# ---
# 343
# ---
# id       abuusei cntu
# label    abuusei cntu
# Name: 343, dtype: object
# ---
# 344
# ---
# id       ac acetic acid
# label    ac acetic acid
# Name: 344, dtype: object
# ---
# 345
# ---
# id       ac am atiriches aroma
# label    ac am atiriches aroma
# Name: 345, dtype: object
# ---
# 346
# ---
# id       ac busasssusd u mos u a nou hnonwurs meldvani ...
# label    ac busasssusd u mos u a nou hnonwurs meldvani ...
# Name: 346, dtype: object
# ---
# 347
# ---
# id       ac citric ac lemon fibers
# label    ac citric ac lemon fibers
# Name: 347, dtype: object
# ---
# 348
# ---
# id       ac citric acid
# label    ac citric acid
# Name: 348, dtype: object
# ---
# 349
# ---
# id       ac citric acid orange flavouring acidity regul...
# label    ac citric acid orange flavouring acidity regul...
# Name: 349, dtype: object
# ---
# 350
# ---
# id       ac ite vegetal
# label    ac ite vegetal
# Name: 350, dtype: object
# ---
# 351
# ---
# id       ac lactic acid
# label    ac lactic acid
# Name: 351, dtype: object
# ---
# 352
# ---
# id       ac malic acid
# label    ac malic acid
# Name: 352, dtype: object
# ---
# 353
# ---
# id       ac malic acid flavouring
# label    ac malic acid flavouring
# Name: 353, dtype: object
# ---
# 354
# ---
# id       ac malico
# label    ac malico
# Name: 354, dtype: object
# ---
# 355
# ---
# id       ac paniorihenique
# label    ac paniorihenique
# Name: 355, dtype: object
# ---
# 356
# ---
# id       ac phosphoric acid may contain traces of sesam...
# label    ac phosphoric acid may contain traces of sesam...
# Name: 356, dtype: object
# ---
# 357
# ---
# id       acacia
# label    acacia
# Name: 357, dtype: object
# ---
# 358
# ---
# id       acacia canned under authority of the cocacola ...
# label    acacia canned under authority of the cocacola ...
# Name: 358, dtype: object
# ---
# 359
# ---
# id       acacia fibers
# label    acacia fibers
# Name: 359, dtype: object
# ---
# 360
# ---
# id       acacia gum
# label    acacia gum
# Name: 360, dtype: object
# ---
# 361
# ---
# id       acacia honey
# label    acacia honey
# Name: 361, dtype: object
# ---
# 362
# ---
# id       acacia jm
# label    acacia jm
# Name: 362, dtype: object
# ---
# 363
# ---
# id       acacia senegal
# label    acacia senegal
# Name: 363, dtype: object
# ---
# 364
# ---
# id       acahuate
# label    acahuate
# Name: 364, dtype: object
# ---
# 365
# ---
# id       acahuètes
# label    acahuètes
# Name: 365, dtype: object
# ---
# 366
# ---
# id       acai
# label    acai
# Name: 366, dtype: object
# ---
# 367
# ---
# id       acai c
# label    acai c
# Name: 367, dtype: object
# ---
# 368
# ---
# id       acai powder
# label    acai powder
# Name: 368, dtype: object
# ---
# 369
# ---
# id       acai pudra
# label    acai pudra
# Name: 369, dtype: object
# ---
# 370
# ---
# id       acaimark
# label    acaimark
# Name: 370, dtype: object
# ---
# 371
# ---
# id       acaipüree
# label    acaipüree
# Name: 371, dtype: object
# ---
# 372
# ---
# id       acaite de girasol
# label    acaite de girasol
# Name: 372, dtype: object
# ---
# 373
# ---
# id       acanthocybium solandri
# label    acanthocybium solandri
# Name: 373, dtype: object
# ---
# 374
# ---
# id       acasulfam k
# label    acasulfam k
# Name: 374, dtype: object
# ---
# 375
# ---
# id       acaí
# label    acaí
# Name: 375, dtype: object
# ---
# 376
# ---
# id       accessoire
# label    accessoire
# Name: 376, dtype: object
# ---
# 377
# ---
# id       accidentant
# label    accidentant
# Name: 377, dtype: object
# ---
# 378
# ---
# id       acciughe
# label    acciughe
# Name: 378, dtype: object
# ---
# 379
# ---
# id       accompagneme céréales
# label    accompagneme céréales
# Name: 379, dtype: object
# ---
# 380
# ---
# id       accompagneme riz cuit
# label    accompagneme riz cuit
# Name: 380, dtype: object
# ---
# 381
# ---
# id       accompagnement
# label    accompagnement
# Name: 381, dtype: object
# ---
# 382
# ---
# id       accompagnement boulgour
# label    accompagnement boulgour
# Name: 382, dtype: object
# ---
# 383
# ---
# id       accompagnement déshydraté
# label    accompagnement déshydraté
# Name: 383, dtype: object
# ---
# 384
# ---
# id       accompagnements
# label    accompagnements
# Name: 384, dtype: object
# ---
# 385
# ---
# id       accompagné d'une sauce cuisinée
# label    accompagné d'une sauce cuisinée
# Name: 385, dtype: object
# ---
# 386
# ---
# id       accompagnées d'un sachet de sauce cuisinée à b...
# label    accompagnées d'un sachet de sauce cuisinée à b...
# Name: 386, dtype: object
# ---
# 387
# ---
# id       accompagnées d'une sauce cuisinée
# label    accompagnées d'une sauce cuisinée
# Name: 387, dtype: object
# ---
# 388
# ---
# id       accompagnés d'une noix de beurre ou d'un jus d...
# label    accompagnés d'une noix de beurre ou d'un jus d...
# Name: 388, dtype: object
# ---
# 389
# ---
# id       accompagnés d'une sauce cuisiné
# label    accompagnés d'une sauce cuisiné
# Name: 389, dtype: object
# ---
# 390
# ---
# id       accompagnés d'une sauce cuisinée
# label    accompagnés d'une sauce cuisinée
# Name: 390, dtype: object
# ---
# 391
# ---
# id       acd
# label    acd
# Name: 391, dtype: object
# ---
# 392
# ---
# id       acde citrique
# label    acde citrique
# Name: 392, dtype: object
# ---
# 393
# ---
# id       acde crtrque
# label    acde crtrque
# Name: 393, dtype: object
# ---
# 394
# ---
# id       acde lactique
# label    acde lactique
# Name: 394, dtype: object
# ---
# 395
# ---
# id       acde sureau
# label    acde sureau
# Name: 395, dtype: object
# ---
# 396
# ---
# id       acdity regulator
# label    acdity regulator
# Name: 396, dtype: object
# ---
# 397
# ---
# id       acdty
# label    acdty
# Name: 397, dtype: object
# ---
# 398
# ---
# id       acdty ealator n
# label    acdty ealator n
# Name: 398, dtype: object
# ---
# 399
# ---
# id       acdulant
# label    acdulant
# Name: 399, dtype: object
# ---
# 400
# ---
# id       ace
# label    ace
# Name: 400, dtype: object
# ---
# 401
# ---
# id       ace laisser aécongeler a heures en chambre fro
# label    ace laisser aécongeler a heures en chambre fro
# Name: 401, dtype: object
# ---
# 402
# ---
# id       acehe vegetdl
# label    acehe vegetdl
# Name: 402, dtype: object
# ---
# 403
# ---
# id       aceit de oliva no hidrogenado
# label    aceit de oliva no hidrogenado
# Name: 403, dtype: object
# ---
# 404
# ---
# id       aceit vegetal
# label    aceit vegetal
# Name: 404, dtype: object
# ---
# 405
# ---
# id       aceite
# label    aceite
# Name: 405, dtype: object
# ---
# 406
# ---
# id       aceite bicarbonato de sodio
# label    aceite bicarbonato de sodio
# Name: 406, dtype: object
# ---
# 407
# ---
# id       aceite cocido basmati
# label    aceite cocido basmati
# Name: 407, dtype: object
# ---
# 408
# ---
# id       aceite comestible
# label    aceite comestible
# Name: 408, dtype: object
# ---
# 409
# ---
# id       aceite comestible de girasol
# label    aceite comestible de girasol
# Name: 409, dtype: object
# ---
# 410
# ---
# id       aceite comestible de soya fortificado con vita...
# label    aceite comestible de soya fortificado con vita...
# Name: 410, dtype: object
# ---
# 411
# ---
# id       aceite comestible puro
# label    aceite comestible puro
# Name: 411, dtype: object
# ---
# 412
# ---
# id       aceite comestible puro de canola
# label    aceite comestible puro de canola
# Name: 412, dtype: object
# ---
# 413
# ---
# id       aceite comestible puro de canola con tbhq como...
# label    aceite comestible puro de canola con tbhq como...
# Name: 413, dtype: object
# ---
# 414
# ---
# id       aceite comestible puro de canola y
# label    aceite comestible puro de canola y
# Name: 414, dtype: object
# ---
# 415
# ---
# id       aceite comestible puro de girasol
# label    aceite comestible puro de girasol
# Name: 415, dtype: object
# ---
# 416
# ---
# id       aceite comestible puro de maíz
# label    aceite comestible puro de maíz
# Name: 416, dtype: object
# ---
# 417
# ---
# id       aceite comestible puro de maíz y
# label    aceite comestible puro de maíz y
# Name: 417, dtype: object
# ---
# 418
# ---
# id       aceite comestible puro de oliva
# label    aceite comestible puro de oliva
# Name: 418, dtype: object
# ---
# 419
# ---
# id       aceite comestible puro de palma
# label    aceite comestible puro de palma
# Name: 419, dtype: object
# ---
# 420
# ---
# id       aceite comestible puro de palma parcialmente h...
# label    aceite comestible puro de palma parcialmente h...
# Name: 420, dtype: object
# ---
# 421
# ---
# id       aceite comestible puro de soya
# label    aceite comestible puro de soya
# Name: 421, dtype: object
# ---
# 422
# ---
# id       aceite comestible puro de soya parcialmente hi...
# label    aceite comestible puro de soya parcialmente hi...
# Name: 422, dtype: object
# ---
# 423
# ---
# id       aceite con infusión de tomate y albahaca
# label    aceite con infusión de tomate y albahaca
# Name: 423, dtype: object
# ---
# 424
# ---
# id       aceite de
# label    aceite de
# Name: 424, dtype: object
# ---
# 425
# ---
# id       aceite de aguacate
# label    aceite de aguacate
# Name: 425, dtype: object
# ---
# 426
# ---
# id       aceite de ajo
# label    aceite de ajo
# Name: 426, dtype: object
# ---
# 427
# ---
# id       aceite de ajonjili tostado
# label    aceite de ajonjili tostado
# Name: 427, dtype: object
# ---
# 428
# ---
# id       aceite de ajonjoli
# label    aceite de ajonjoli
# Name: 428, dtype: object
# ---
# 429
# ---
# id       aceite de ajonjolí extra virgen
# label    aceite de ajonjolí extra virgen
# Name: 429, dtype: object
# ---
# 430
# ---
# id       aceite de ajonjolí extra virgen con extracto d...
# label    aceite de ajonjolí extra virgen con extracto d...
# Name: 430, dtype: object
# ---
# 431
# ---
# id       aceite de ajonjolí y soya sabor oriental
# label    aceite de ajonjolí y soya sabor oriental
# Name: 431, dtype: object
# ---
# 432
# ---
# id       aceite de ajonjolíi refinado
# label    aceite de ajonjolíi refinado
# Name: 432, dtype: object
# ---
# 433
# ---
# id       aceite de algodon
# label    aceite de algodon
# Name: 433, dtype: object
# ---
# 434
# ---
# id       aceite de algodón
# label    aceite de algodón
# Name: 434, dtype: object
# ---
# 435
# ---
# id       aceite de almendras amargas
# label    aceite de almendras amargas
# Name: 435, dtype: object
# ---
# 436
# ---
# id       aceite de almidón
# label    aceite de almidón
# Name: 436, dtype: object
# ---
# 437
# ---
# id       aceite de arroz y sal marina
# label    aceite de arroz y sal marina
# Name: 437, dtype: object
# ---
# 438
# ---
# id       aceite de cacahuate tostado
# label    aceite de cacahuate tostado
# Name: 438, dtype: object
# ---
# 439
# ---
# id       aceite de cacahuete
# label    aceite de cacahuete
# Name: 439, dtype: object
# ---
# 440
# ---
# id       aceite de canola
# label    aceite de canola
# Name: 440, dtype: object
# ---
# 441
# ---
# id       aceite de canola cartamo y
# label    aceite de canola cartamo y
# Name: 441, dtype: object
# ---
# 442
# ---
# id       aceite de canola parcialmente hidrogenado
# label    aceite de canola parcialmente hidrogenado
# Name: 442, dtype: object
# ---
# 443
# ---
# id       aceite de canola y
# label    aceite de canola y
# Name: 443, dtype: object
# ---
# 444
# ---
# id       aceite de canola y condimento natural chile limón
# label    aceite de canola y condimento natural chile limón
# Name: 444, dtype: object
# ---
# 445
# ---
# id       aceite de canola y sazonador
# label    aceite de canola y sazonador
# Name: 445, dtype: object
# ---
# 446
# ---
# id       aceite de caramelo orgánico
# label    aceite de caramelo orgánico
# Name: 446, dtype: object
# ---
# 447
# ---
# id       aceite de cartamo
# label    aceite de cartamo
# Name: 447, dtype: object
# ---
# 448
# ---
# id       aceite de coco
# label    aceite de coco
# Name: 448, dtype: object
# ---
# 449
# ---
# id       aceite de coco organico extra virgen
# label    aceite de coco organico extra virgen
# Name: 449, dtype: object
# ---
# 450
# ---
# id       aceite de coco orgánico
# label    aceite de coco orgánico
# Name: 450, dtype: object
# ---
# 451
# ---
# id       aceite de coco orgánico sin refinar extraído m...
# label    aceite de coco orgánico sin refinar extraído m...
# Name: 451, dtype: object
# ---
# 452
# ---
# id       aceite de coco parcialmente hidrogenada
# label    aceite de coco parcialmente hidrogenada
# Name: 452, dtype: object
# ---
# 453
# ---
# id       aceite de coco parcialmente hidrogenado
# label    aceite de coco parcialmente hidrogenado
# Name: 453, dtype: object
# ---
# 454
# ---
# id       aceite de coco prensado en frío
# label    aceite de coco prensado en frío
# Name: 454, dtype: object
# ---
# 455
# ---
# id       aceite de coco refinado
# label    aceite de coco refinado
# Name: 455, dtype: object
# ---
# 456
# ---
# id       aceite de coco refinado desodorizado no hidrog...
# label    aceite de coco refinado desodorizado no hidrog...
# Name: 456, dtype: object
# ---
# 457
# ---
# id       aceite de coco virgen
# label    aceite de coco virgen
# Name: 457, dtype: object
# ---
# 458
# ---
# id       aceite de coco y aceite de palma
# label    aceite de coco y aceite de palma
# Name: 458, dtype: object
# ---
# 459
# ---
# id       aceite de colza
# label    aceite de colza
# Name: 459, dtype: object
# ---
# 460
# ---
# id       aceite de cártamo
# label    aceite de cártamo
# Name: 460, dtype: object
# ---
# 461
# ---
# id       aceite de cáñamo
# label    aceite de cáñamo
# Name: 461, dtype: object
# ---
# 462
# ---
# id       aceite de eucalipto
# label    aceite de eucalipto
# Name: 462, dtype: object
# ---
# 463
# ---
# id       aceite de fritu aceites vegetales de girasol y...
# label    aceite de fritu aceites vegetales de girasol y...
# Name: 463, dtype: object
# ---
# 464
# ---
# id       aceite de girasol
# label    aceite de girasol
# Name: 464, dtype: object
# ---
# 465
# ---
# id       aceite de girasol alto oleico
# label    aceite de girasol alto oleico
# Name: 465, dtype: object
# ---
# 466
# ---
# id       aceite de girasol alto oleico y aceite de oliva
# label    aceite de girasol alto oleico y aceite de oliva
# Name: 466, dtype: object
# ---
# 467
# ---
# id       aceite de girasol alto oleico y aroma de chili
# label    aceite de girasol alto oleico y aroma de chili
# Name: 467, dtype: object
# ---
# 468
# ---
# id       aceite de girasol altooleico
# label    aceite de girasol altooleico
# Name: 468, dtype: object
# ---
# 469
# ---
# id       aceite de girasol de primera presión en frío
# label    aceite de girasol de primera presión en frío
# Name: 469, dtype: object
# ---
# 470
# ---
# id       aceite de girasol en polvo
# label    aceite de girasol en polvo
# Name: 470, dtype: object
# ---
# 471
# ---
# id       aceite de girasol especies
# label    aceite de girasol especies
# Name: 471, dtype: object
# ---
# 472
# ---
# id       aceite de girasol fibra prebiótica
# label    aceite de girasol fibra prebiótica
# Name: 472, dtype: object
# ---
# 473
# ---
# id       aceite de girasol no hidrogenado
# label    aceite de girasol no hidrogenado
# Name: 473, dtype: object
# ---
# 474
# ---
# id       aceite de girasol prensado en frío
# label    aceite de girasol prensado en frío
# Name: 474, dtype: object
# ---
# 475
# ---
# id       aceite de girasol refinado
# label    aceite de girasol refinado
# Name: 475, dtype: object
# ---
# 476
# ---
# id       aceite de girasol totalmente hidrogenado
# label    aceite de girasol totalmente hidrogenado
# Name: 476, dtype: object
# ---
# 477
# ---
# id       aceite de girasol y aceite de oliva virgen
# label    aceite de girasol y aceite de oliva virgen
# Name: 477, dtype: object
# ---
# 478
# ---
# id       aceite de girasol y aceite de soja en proporci...
# label    aceite de girasol y aceite de soja en proporci...
# Name: 478, dtype: object
# ---
# 479
# ---
# id       aceite de girasol y aroma
# label    aceite de girasol y aroma
# Name: 479, dtype: object
# ---
# 480
# ---
# id       aceite de girasol y emulgen lecitina de soja
# label    aceite de girasol y emulgen lecitina de soja
# Name: 480, dtype: object
# ---
# 481
# ---
# id       aceite de girasol y especias
# label    aceite de girasol y especias
# Name: 481, dtype: object
# ---
# 482
# ---
# id       aceite de girasol y grasa de coco
# label    aceite de girasol y grasa de coco
# Name: 482, dtype: object
# ---
# 483
# ---
# id       aceite de girasol y manteca coco
# label    aceite de girasol y manteca coco
# Name: 483, dtype: object
# ---
# 484
# ---
# id       aceite de girasol y manteca de coco
# label    aceite de girasol y manteca de coco
# Name: 484, dtype: object
# ---
# 485
# ---
# id       aceite de girasol y sal
# label    aceite de girasol y sal
# Name: 485, dtype: object
# ---
# 486
# ---
# id       aceite de girasol y saí
# label    aceite de girasol y saí
# Name: 486, dtype: object
# ---
# 487
# ---
# id       aceite de girasoly sal
# label    aceite de girasoly sal
# Name: 487, dtype: object
# ---
# 488
# ---
# id       aceite de grasol
# label    aceite de grasol
# Name: 488, dtype: object
# ---
# 489
# ---
# id       aceite de gîrasol y
# label    aceite de gîrasol y
# Name: 489, dtype: object
# ---
# 490
# ---
# id       aceite de hígado de balao
# label    aceite de hígado de balao
# Name: 490, dtype: object
# ---
# 491
# ---
# id       aceite de karité y colza
# label    aceite de karité y colza
# Name: 491, dtype: object
# ---
# 492
# ---
# id       aceite de limón
# label    aceite de limón
# Name: 492, dtype: object
# ---
# 493
# ---
# id       aceite de maiz
# label    aceite de maiz
# Name: 493, dtype: object
# ---
# 494
# ---
# id       aceite de maiz parcialmente hidrogenado
# label    aceite de maiz parcialmente hidrogenado
# Name: 494, dtype: object
# ---
# 495
# ---
# id       aceite de maravilla
# label    aceite de maravilla
# Name: 495, dtype: object
# ---
# 496
# ---
# id       aceite de maíz
# label    aceite de maíz
# Name: 496, dtype: object
# ---
# 497
# ---
# id       aceite de maíz amarillo
# label    aceite de maíz amarillo
# Name: 497, dtype: object
# ---
# 498
# ---
# id       aceite de maíz vegetal
# label    aceite de maíz vegetal
# Name: 498, dtype: object
# ---
# 499
# ---
# id       aceite de maíz y esencia de vainilla
# label    aceite de maíz y esencia de vainilla
# Name: 499, dtype: object

# %%
data_ingredients = data_ingredients.reset_index(drop=True)
data_ingredients['id'] = data_ingredients['id'].replace(to_replace =' ', value = '_', regex = True)
data_ingredients
# Out:
#                                                        id  \
# 0                                                     a_a
# 1                                                 a_a_cuc
# 2                                         a_acido_citrico
# 3                        a_appellation_d'origine_protégée
# 4       a_appellation_d'origine_protégée_produit_élabo...
# ...                                                   ...
# 125125                           ﬂocons_d'avoine_complets
# 125126                                  ﬂocons_d'épeautre
# 125127                                      ﬂocons_de_blé
# 125128                           ﬂocons_de_pomme_de_terre
# 125129                          ﬂocons_de_pommes_de_terre
#
#                                                     label
# 0                                                     a a
# 1                                                 a a cuc
# 2                                         a acido citrico
# 3                        a appellation d'origine protégée
# 4       a appellation d'origine protégée produit élabo...
# ...                                                   ...
# 125125                           ﬂocons d'avoine complets
# 125126                                  ﬂocons d'épeautre
# 125127                                      ﬂocons de blé
# 125128                           ﬂocons de pomme de terre
# 125129                          ﬂocons de pommes de terre
#
# [125130 rows x 2 columns]

# %%
data_ingredients.to_csv('ingredients.csv', index=True, index_label="index", encoding='utf-8')

# %% [markdown]
# ### Create countries dataset (before formatting countries for products)

# %%
allCountries = [] 
for index, text in enumerate(data_products['countries_en']):
    if text is not None:
        countries = text.split("|")
        for country in countries:
            if(country != '') : allCountries.append(country)

# %%
len(allCountries)
# Out:
# 81754

# %%
# DISTINCT
allCountries = list(set(allCountries))
print(len(allCountries))
# ABC SORT
allCountries = sorted(allCountries, key=str.lower)
# Out:
# 263

# %%
data_countries = pd.DataFrame(data=allCountries, columns=['id'])

# %%
data_countries['label'] = allCountries

# %%
i = 0
iStop = i + 100
while i < iStop:
    print("---")
    print(i)
    print("---")
    print(data_countries.iloc[i])
    i += 1
# Out:
# ---
# 0
# ---
# id       Afghanistan
# label    Afghanistan
# Name: 0, dtype: object
# ---
# 1
# ---
# id       Albania
# label    Albania
# Name: 1, dtype: object
# ---
# 2
# ---
# id       Algeria
# label    Algeria
# Name: 2, dtype: object
# ---
# 3
# ---
# id       Allemagne
# label    Allemagne
# Name: 3, dtype: object
# ---
# 4
# ---
# id       Andorra
# label    Andorra
# Name: 4, dtype: object
# ---
# 5
# ---
# id       Anguilla
# label    Anguilla
# Name: 5, dtype: object
# ---
# 6
# ---
# id       Argentina
# label    Argentina
# Name: 6, dtype: object
# ---
# 7
# ---
# id       Argentina-espanol
# label    Argentina-espanol
# Name: 7, dtype: object
# ---
# 8
# ---
# id       Armenia-pyсский
# label    Armenia-pyсский
# Name: 8, dtype: object
# ---
# 9
# ---
# id       Aruba-espanol
# label    Aruba-espanol
# Name: 9, dtype: object
# ---
# 10
# ---
# id       Asia-pacific
# label    Asia-pacific
# Name: 10, dtype: object
# ---
# 11
# ---
# id       Australia
# label    Australia
# Name: 11, dtype: object
# ---
# 12
# ---
# id       Australia-english
# label    Australia-english
# Name: 12, dtype: object
# ---
# 13
# ---
# id       Austria
# label    Austria
# Name: 13, dtype: object
# ---
# 14
# ---
# id       Austria-deutsch
# label    Austria-deutsch
# Name: 14, dtype: object
# ---
# 15
# ---
# id       Autriche
# label    Autriche
# Name: 15, dtype: object
# ---
# 16
# ---
# id       Azerbaijan
# label    Azerbaijan
# Name: 16, dtype: object
# ---
# 17
# ---
# id       Azerbaijan-русский
# label    Azerbaijan-русский
# Name: 17, dtype: object
# ---
# 18
# ---
# id       Belarus
# label    Belarus
# Name: 18, dtype: object
# ---
# 19
# ---
# id       Belarus-pyсский
# label    Belarus-pyсский
# Name: 19, dtype: object
# ---
# 20
# ---
# id       belgica
# label    belgica
# Name: 20, dtype: object
# ---
# 21
# ---
# id       belgien
# label    belgien
# Name: 21, dtype: object
# ---
# 22
# ---
# id       Belgique
# label    Belgique
# Name: 22, dtype: object
# ---
# 23
# ---
# id       Belgium
# label    Belgium
# Name: 23, dtype: object
# ---
# 24
# ---
# id       Belgium-francais
# label    Belgium-francais
# Name: 24, dtype: object
# ---
# 25
# ---
# id       Belgium-nederlands
# label    Belgium-nederlands
# Name: 25, dtype: object
# ---
# 26
# ---
# id       Bolivia
# label    Bolivia
# Name: 26, dtype: object
# ---
# 27
# ---
# id       Bolivia-espanol
# label    Bolivia-espanol
# Name: 27, dtype: object
# ---
# 28
# ---
# id       Bosnia and Herzegovina
# label    Bosnia and Herzegovina
# Name: 28, dtype: object
# ---
# 29
# ---
# id       Bosnia-i-hercegovina-bosnian
# label    Bosnia-i-hercegovina-bosnian
# Name: 29, dtype: object
# ---
# 30
# ---
# id       Botswana-english
# label    Botswana-english
# Name: 30, dtype: object
# ---
# 31
# ---
# id       Brazil
# label    Brazil
# Name: 31, dtype: object
# ---
# 32
# ---
# id       Brazil-portugues
# label    Brazil-portugues
# Name: 32, dtype: object
# ---
# 33
# ---
# id       Bulgaria
# label    Bulgaria
# Name: 33, dtype: object
# ---
# 34
# ---
# id       Bulgaria-български
# label    Bulgaria-български
# Name: 34, dtype: object
# ---
# 35
# ---
# id       Burkina Faso
# label    Burkina Faso
# Name: 35, dtype: object
# ---
# 36
# ---
# id       Cambodia
# label    Cambodia
# Name: 36, dtype: object
# ---
# 37
# ---
# id       Cambodia-english
# label    Cambodia-english
# Name: 37, dtype: object
# ---
# 38
# ---
# id       Cambodia-ភាសាខ្មែរ
# label    Cambodia-ភាសាខ្មែរ
# Name: 38, dtype: object
# ---
# 39
# ---
# id       Cameroon
# label    Cameroon
# Name: 39, dtype: object
# ---
# 40
# ---
# id       Canada
# label    Canada
# Name: 40, dtype: object
# ---
# 41
# ---
# id       Canada-english
# label    Canada-english
# Name: 41, dtype: object
# ---
# 42
# ---
# id       Canada-francais
# label    Canada-francais
# Name: 42, dtype: object
# ---
# 43
# ---
# id       cantabria
# label    cantabria
# Name: 43, dtype: object
# ---
# 44
# ---
# id       Chile
# label    Chile
# Name: 44, dtype: object
# ---
# 45
# ---
# id       Chile-espanol
# label    Chile-espanol
# Name: 45, dtype: object
# ---
# 46
# ---
# id       China
# label    China
# Name: 46, dtype: object
# ---
# 47
# ---
# id       China-中文
# label    China-中文
# Name: 47, dtype: object
# ---
# 48
# ---
# id       Colombia
# label    Colombia
# Name: 48, dtype: object
# ---
# 49
# ---
# id       Colombia-espanol
# label    Colombia-espanol
# Name: 49, dtype: object
# ---
# 50
# ---
# id       Costa Rica
# label    Costa Rica
# Name: 50, dtype: object
# ---
# 51
# ---
# id       Costa-rica-espanol
# label    Costa-rica-espanol
# Name: 51, dtype: object
# ---
# 52
# ---
# id       Croatia
# label    Croatia
# Name: 52, dtype: object
# ---
# 53
# ---
# id       Croatia-hrvatski
# label    Croatia-hrvatski
# Name: 53, dtype: object
# ---
# 54
# ---
# id       Cuba
# label    Cuba
# Name: 54, dtype: object
# ---
# 55
# ---
# id       Cyprus
# label    Cyprus
# Name: 55, dtype: object
# ---
# 56
# ---
# id       Cyprus-ελληνικά
# label    Cyprus-ελληνικά
# Name: 56, dtype: object
# ---
# 57
# ---
# id       Czech Republic
# label    Czech Republic
# Name: 57, dtype: object
# ---
# 58
# ---
# id       Czech-republic-čeština
# label    Czech-republic-čeština
# Name: 58, dtype: object
# ---
# 59
# ---
# id       Côte d'Ivoire
# label    Côte d'Ivoire
# Name: 59, dtype: object
# ---
# 60
# ---
# id       Democratic Republic of the Congo
# label    Democratic Republic of the Congo
# Name: 60, dtype: object
# ---
# 61
# ---
# id       Denmark
# label    Denmark
# Name: 61, dtype: object
# ---
# 62
# ---
# id       Denmark-dansk
# label    Denmark-dansk
# Name: 62, dtype: object
# ---
# 63
# ---
# id       deutschland
# label    deutschland
# Name: 63, dtype: object
# ---
# 64
# ---
# id       Djibouti
# label    Djibouti
# Name: 64, dtype: object
# ---
# 65
# ---
# id       dom-tom
# label    dom-tom
# Name: 65, dtype: object
# ---
# 66
# ---
# id       Dominica
# label    Dominica
# Name: 66, dtype: object
# ---
# 67
# ---
# id       Dominican Republic
# label    Dominican Republic
# Name: 67, dtype: object
# ---
# 68
# ---
# id       Ecuador
# label    Ecuador
# Name: 68, dtype: object
# ---
# 69
# ---
# id       Ecuador-espanol
# label    Ecuador-espanol
# Name: 69, dtype: object
# ---
# 70
# ---
# id       Egypt
# label    Egypt
# Name: 70, dtype: object
# ---
# 71
# ---
# id       El Salvador
# label    El Salvador
# Name: 71, dtype: object
# ---
# 72
# ---
# id       El-salvador-espanol
# label    El-salvador-espanol
# Name: 72, dtype: object
# ---
# 73
# ---
# id       En
# label    En
# Name: 73, dtype: object
# ---
# 74
# ---
# id       Estonia
# label    Estonia
# Name: 74, dtype: object
# ---
# 75
# ---
# id       Estonia-eesti
# label    Estonia-eesti
# Name: 75, dtype: object
# ---
# 76
# ---
# id       Europe
# label    Europe
# Name: 76, dtype: object
# ---
# 77
# ---
# id       European Union
# label    European Union
# Name: 77, dtype: object
# ---
# 78
# ---
# id       Fiji
# label    Fiji
# Name: 78, dtype: object
# ---
# 79
# ---
# id       Finland
# label    Finland
# Name: 79, dtype: object
# ---
# 80
# ---
# id       Finland-suomi
# label    Finland-suomi
# Name: 80, dtype: object
# ---
# 81
# ---
# id       France
# label    France
# Name: 81, dtype: object
# ---
# 82
# ---
# id       France-francais
# label    France-francais
# Name: 82, dtype: object
# ---
# 83
# ---
# id       francia
# label    francia
# Name: 83, dtype: object
# ---
# 84
# ---
# id       frankreich
# label    frankreich
# Name: 84, dtype: object
# ---
# 85
# ---
# id       French Guiana
# label    French Guiana
# Name: 85, dtype: object
# ---
# 86
# ---
# id       French Polynesia
# label    French Polynesia
# Name: 86, dtype: object
# ---
# 87
# ---
# id       Gabon
# label    Gabon
# Name: 87, dtype: object
# ---
# 88
# ---
# id       Georgia-ქართული
# label    Georgia-ქართული
# Name: 88, dtype: object
# ---
# 89
# ---
# id       Germany
# label    Germany
# Name: 89, dtype: object
# ---
# 90
# ---
# id       Germany-deutsch
# label    Germany-deutsch
# Name: 90, dtype: object
# ---
# 91
# ---
# id       Ghana-english
# label    Ghana-english
# Name: 91, dtype: object
# ---
# 92
# ---
# id       Greece
# label    Greece
# Name: 92, dtype: object
# ---
# 93
# ---
# id       Greece-ελληνικά
# label    Greece-ελληνικά
# Name: 93, dtype: object
# ---
# 94
# ---
# id       Guadeloupe
# label    Guadeloupe
# Name: 94, dtype: object
# ---
# 95
# ---
# id       Guatemala
# label    Guatemala
# Name: 95, dtype: object
# ---
# 96
# ---
# id       Guatemala-espanol
# label    Guatemala-espanol
# Name: 96, dtype: object
# ---
# 97
# ---
# id       Haiti
# label    Haiti
# Name: 97, dtype: object
# ---
# 98
# ---
# id       Honduras
# label    Honduras
# Name: 98, dtype: object
# ---
# 99
# ---
# id       Honduras-espanol
# label    Honduras-espanol
# Name: 99, dtype: object

# %%
data_countries = data_countries.reset_index(drop=True)
data_countries['id'] = data_countries['id'].str.lower().replace(to_replace =' ', value = '_', regex = True)
data_countries
# Out:
#                      id               label
# 0           afghanistan         Afghanistan
# 1               albania             Albania
# 2               algeria             Algeria
# 3             allemagne           Allemagne
# 4               andorra             Andorra
# ..                  ...                 ...
# 258             vietnam             Vietnam
# 259  vietnam-tiếng-việt  Vietnam-tiếng-việt
# 260               yemen               Yemen
# 261      zambia-english      Zambia-english
# 262       åland_islands       Åland Islands
#
# [263 rows x 2 columns]

# %%
data_countries.to_csv('countries.csv', index=True, index_label="index", encoding='utf-8')

# %% [markdown]
# ### Create products dataset

# %%
data_products['countries_en'] = data_products['countries_en'].str.lower().replace(to_replace =' ', value = '_', regex = True)
data_products['ingredients_text'] = data_products['ingredients_text'].str.lower().replace(to_replace =' ', value = '_', regex = True)

# %%
data_products['countries_en'] = data_products['countries_en'].astype(str)
data_products['allergens'] = data_products['allergens'].astype(str)

# %%
class Product:
    def __init__(self, code, product_name, categories_tags, categories_en, countries_en, ingredients_text, allergens, nutriscore_grade, nova_group, main_category, energy_kcal_100g, fat_100g, saturated_fat_100g, trans_fat_100g, cholesterol_100g, carbohydrates_100g, sugars_100g, fiber_100g, proteins_100g, salt_100g, sodium_100g):
        self.code = code
#         self.url = url
        self.product_name = product_name
#         self.categories = categories
        self.main_category = main_category
        
        self.categories = categories_tags.split("|")
#         self.categories_tags = categories_tags
#         self.categories_en = categories_en
        self.countries = countries_en.split("|")
#         self.countries_en = countries_en
        self.ingredients = ingredients_text.split("|")
#         self.ingredients_text = ingredients_text
#         self.allergens = allergens.split("|")
#         self.allergens = allergens
#         if nutriscore_score is not None: self.nutriscore_score = nutriscore_score
        if nutriscore_grade is not None: self.nutriscore_grade = nutriscore_grade
        if nova_group is not None: self.nova_group = nova_group
#         if pnns_groups_1 is not None: self.pnns_groups_1 = pnns_groups_1
#         if pnns_groups_2 is not None: self.pnns_groups_2 = pnns_groups_2
#         if main_category_en is not None: self.main_category_en = main_category_en
#         if energy_kj_100g is not None: self.energy_kj_100g = energy_kj_100g
#         if energy_kcal_100g is not None: self.energy_kcal_100g = energy_kcal_100g
#         if energy_100g is not None: self.energy_100g = energy_100g
        if fat_100g is not None: self.fat_100g = fat_100g
        if saturated_fat_100g is not None: self.saturated_fat_100g = saturated_fat_100g
        if trans_fat_100g is not None: self.trans_fat_100g = trans_fat_100g
        if cholesterol_100g is not None: self.cholesterol_100g = cholesterol_100g
        if carbohydrates_100g is not None: self.carbohydrates_100g = carbohydrates_100g
        if sugars_100g is not None: self.sugars_100g = sugars_100g
        if fiber_100g is not None: self.fiber_100g = fiber_100g
        if proteins_100g is not None: self.proteins_100g = proteins_100g
        if salt_100g is not None: self.salt_100g = salt_100g
        if sodium_100g is not None: self.sodium_100g = sodium_100g
#         if nutrition_score_fr_100g is not None: self.nutrition_score_fr_100g = nutrition_score_fr_100g
        
        
class OpenFoodFact():
    def __init__(self, products: List[Product]):
        self.products = products
        
products = [(Product(row['code'], row['product_name'], row['categories_tags'], row['categories_en'], row['countries_en'], row['ingredients_text'], row['allergens'], row['nutriscore_grade'], row['nova_group'], row['main_category'], row['energy-kcal_100g'], row['fat_100g'], row['saturated-fat_100g'], row['trans-fat_100g'], row['cholesterol_100g'], row['carbohydrates_100g'], row['sugars_100g'], row['fiber_100g'], row['proteins_100g'], row['salt_100g'], row['sodium_100g'])) for index, row in data_products.iterrows()]

openfoodfact = OpenFoodFact(products=products)
# products[1].ingredients

# %%
json_data = json.dumps(openfoodfact, default=lambda o: o.__dict__, indent=4, ensure_ascii=False)
text_file = open("products.json", "w", encoding='utf-8')
text_file.write(json_data)
text_file.close()

# %%
# products[len(products)-1].__dict__
